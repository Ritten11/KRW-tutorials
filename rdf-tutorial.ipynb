# %% [markdown]
# # Knowledge Representation on the Web -- RDF tutorial
#
# In this tutorial we'll learn the basics of interacting with RDF graphs with Python. We'll be using rdflib for this, a widely used Ptyhon library for RDF (all documentation can be found [here](https://rdflib.readthedocs.io/en/stable/index.html))

# %% [markdown]
# ## Imports
# These are the main classes and types we'll be using from rdflib

# %%
import sys
# !{sys.executable} -m pip install rdflib

from rdflib import Graph, ConjunctiveGraph, Literal, BNode, Namespace, RDF, URIRef
from rdflib.namespace import DC, FOAF, RDFS

import pprint

# %% [markdown]
# ## Loading data remotely and from files
#
# rdflib accepts importing RDF data from a variety of sources, either locally from a file (including an extensive support of serializations), or remotely via a URI (this is a great way of checking practically if URIs return RDF according to the 3rd Linked Data principle).
#
# A Graph object is always required to load triples.
# **Note**: to load quads, and hence supporting named graphs, you'll need to use an instance of ConjunctiveGraph instead
#
# **Exercise 1**
#
# For each step, use a different cell:
# 1. create two graphs using rdflib:
#     - and load one with triples from the site https://csarven.ca/ and/or http://www.w3.org/People/Berners-Lee/card
#     - load one with triples from ./data/ingredients.rdf.

# %%
#TIP: look at the documentation of the rdflib library for how to LOAD and PARSE a graph - https://rdflib.readthedocs.io/en/stable/gettingstarted.html

# Create a Graph

def print_graph(loc):

    g = Graph()

    g.parse(loc)

    print(g.serialize(format="turtle"))
# g = Graph()

# Parse in an RDF file hosted on the Internet
print_graph("http://www.w3.org/People/Berners-Lee/card")

# print(g.serialize(format="turtle"))
# Out:
# @prefix : <http://xmlns.com/foaf/0.1/> .
# @prefix Be: <https://www.w3.org/People/Berners-Lee/> .
# @prefix Pub: <https://timbl.com/timbl/Public/> .
# @prefix blog: <http://dig.csail.mit.edu/breadcrumbs/blog/> .
# @prefix card: <https://www.w3.org/People/Berners-Lee/card#> .
# @prefix cc: <http://creativecommons.org/ns#> .
# @prefix cert: <http://www.w3.org/ns/auth/cert#> .
# @prefix con: <http://www.w3.org/2000/10/swap/pim/contact#> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix doap: <http://usefulinc.com/ns/doap#> .
# @prefix geo: <http://www.w3.org/2003/01/geo/wgs84_pos#> .
# @prefix ldp: <http://www.w3.org/ns/ldp#> .
# @prefix s: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <http://schema.org/> .
# @prefix sioc: <http://rdfs.org/sioc/ns#> .
# @prefix solid: <http://www.w3.org/ns/solid/terms#> .
# @prefix space: <http://www.w3.org/ns/pim/space#> .
# @prefix vcard: <http://www.w3.org/2006/vcard/ns#> .
# @prefix w3c: <http://www.w3.org/data#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://dig.csail.mit.edu/2005/ajar/ajaw/data#Tabulator> doap:developer card:i .
#
# <http://dig.csail.mit.edu/2007/01/camp/data#course> :maker card:i .
#
# <http://dig.csail.mit.edu/data#DIG> :member card:i .
#
# <http://wiki.ontoworld.org/index.php/_IRW2006> dc:title "Identity, Reference and the Web workshop 2006" ;
#     con:participant card:i .
#
# <http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01> s:label "The Next Wave of the Web (Plenary Panel)" ;
#     con:participant card:i .
#
# <http://www.w3.org/2000/10/swap/data#Cwm> doap:developer card:i .
#
# <http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk> dct:title "Designing the Web for an Open Society" ;
#     :maker card:i .
#
# w3c:W3C :member card:i .
#
# <https://www.w3.org/DesignIssues/Overview.html> dc:title "Design Issues for the World Wide Web" ;
#     :maker card:i .
#
# Be:card a :PersonalProfileDocument ;
#     cc:license <http://creativecommons.org/licenses/by-nc/3.0/> ;
#     dc:title "Tim Berners-Lee's FOAF file" ;
#     :maker card:i ;
#     :primaryTopic card:i .
#
# blog:4 dc:title "timbl's blog on DIG" ;
#     s:seeAlso <http://dig.csail.mit.edu/breadcrumbs/blog/feed/4> ;
#     :maker card:i .
#
# Pub:friends.ttl a :PersonalProfileDocument ;
#     cc:license <http://creativecommons.org/licenses/by-nc/3.0/> ;
#     dc:title "Tim Berners-Lee's editable profile" ;
#     :maker card:i ;
#     :primaryTopic card:i .
#
# card:i a con:Male,
#         :Person ;
#     s:label "Tim Berners-Lee" ;
#     sioc:avatar <https://www.w3.org/People/Berners-Lee/images/timbl-image-by-Coz-cropped.jpg> ;
#     schema:owns <https://timblbot.inrupt.net/profile/card#me> ;
#     s:seeAlso Pub:friends.ttl ;
#     con:assistant card:amy ;
#     con:homePage Be: ;
#     con:office [ con:address [ con:city "Cambridge" ;
#                     con:country "USA" ;
#                     con:postalCode "02139" ;
#                     con:street "32 Vassar Street" ;
#                     con:street2 "MIT CSAIL Building 32" ] ;
#             geo:location [ geo:lat "42.361860" ;
#                     geo:long "-71.091840" ] ] ;
#     con:preferredURI "https://www.w3.org/People/Berners-Lee/card#i" ;
#     con:publicHomePage Be: ;
#     vcard:fn "Tim Berners-Lee" ;
#     vcard:hasAddress [ a vcard:Work ;
#             vcard:locality "Cambridge" ;
#             vcard:postal-code "02139" ;
#             vcard:region "MA" ;
#             vcard:street-address "32 Vassar Street" ] ;
#     cert:key [ a cert:RSAPublicKey ;
#             cert:exponent 65537 ;
#             cert:modulus "..."^^xsd:hexBinary ] ;
#     ldp:inbox Pub:Inbox ;
#     space:preferencesFile <https://timbl.com/timbl/Data/preferences.n3> ;
#     space:storage Pub:,
#         <https://timbl.inrupt.net/>,
#         <https://timbl.solid.community/> ;
#     solid:editableProfile Pub:friends.ttl ;
#     solid:oidcIssuer <https://timbl.com> ;
#     solid:profileBackgroundColor "#ffffff" ;
#     solid:profileHighlightColor "#00467E" ;
#     solid:publicTypeIndex Pub:PublicTypeIndex.ttl ;
#     :account <http://en.wikipedia.org/wiki/User:Timbl>,
#         <http://twitter.com/timberners_lee>,
#         <http://www.reddit.com/user/timbl/> ;
#     :based_near [ geo:lat "42.361860" ;
#             geo:long "-71.091840" ] ;
#     :family_name "Berners-Lee" ;
#     :givenname "Timothy" ;
#     :homepage Be: ;
#     :img <https://www.w3.org/Press/Stock/Berners-Lee/2001-europaeum-eighth.jpg> ;
#     :mbox <mailto:timbl@w3.org> ;
#     :mbox_sha1sum "965c47c5a70db7407210cef6e4e6f5374a525c5c" ;
#     :name "Timothy Berners-Lee" ;
#     :nick "TimBL",
#         "timbl" ;
#     :openid Be: ;
#     :title "Sir" ;
#     :weblog blog:4 ;
#     :workplaceHomepage <https://www.w3.org/> .

# %%
print_graph("https://csarven.ca/")
# Out:
# @prefix cs: <https://csarven.ca/> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix dok: <https://csarven.ca/dokie.li.inbox/> .
# @prefix html: <http://www.w3.org/ns/iana/media-types/text/html#> .
# @prefix inbox: <https://csarven.ca/inbox/> .
# @prefix key: <https://csarven.ca/key/> .
# @prefix ldp: <http://www.w3.org/ns/ldp#> .
# @prefix medi: <https://csarven.ca/media/> .
# @prefix n0: <https://csarven.ca/archives/> .
# @prefix n1: <http://www.w3.org/ns/iana/media-types/application/atom+xml#> .
# @prefix pl: <http://www.w3.org/ns/iana/media-types/text/plain#> .
# @prefix pre: <https://csarven.ca/presentations/> .
# @prefix scr: <https://csarven.ca/scripts/> .
# @prefix space: <http://www.w3.org/ns/pim/space#> .
# @prefix stat: <http://www.w3.org/ns/posix/stat#> .
# @prefix tmp: <https://csarven.ca/tmp/> .
# @prefix tur: <http://www.w3.org/ns/iana/media-types/text/turtle#> .
# @prefix vnd: <http://www.w3.org/ns/iana/media-types/image/vnd.microsoft.icon#> .
# @prefix xm: <http://www.w3.org/ns/iana/media-types/application/xml#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# cs: a ldp:BasicContainer,
#         ldp:Container,
#         space:Storage ;
#     dct:modified "2023-02-03T20:08:07+00:00"^^xsd:dateTime ;
#     ldp:contains cs:7,
#         cs:about,
#         n0:,
#         cs:atom,
#         cs:call-for-linked-research,
#         cs:communication-protocols,
#         cs:complexity-of-development-part-1,
#         cs:contacts,
#         cs:cooling-down-web-science,
#         cs:css-background-order-and-w3c-specification-ambiguity-in-browsers,
#         cs:css-specificity-and-selectors,
#         cs:cv,
#         cs:dandelion-design,
#         dok:,
#         cs:dokieli,
#         cs:dokieli-rww,
#         cs:enabling-accessible-knowledge,
#         cs:faipdaaf,
#         cs:favicon.ico,
#         cs:five-months,
#         cs:front-end-developer-integrator,
#         cs:future-of-css-naked-day,
#         cs:good-tips-and-customer-experience,
#         cs:google-deutschland-stole-my-article,
#         cs:googlebot-anchor-indexability-test,
#         cs:googlef24ee8d5af3f254f.html,
#         cs:hiding-email-addresses,
#         cs:how-to-create-a-linked-data-site,
#         cs:html-minimal-verbose,
#         cs:html-overview,
#         cs:human-language-and-html,
#         cs:i-am-here-now,
#         cs:identical-tabindex-values-and-group-iterations,
#         inbox:,
#         cs:index.html,
#         cs:internal-seo-guidelines,
#         cs:interview-with-steven-pemberton,
#         cs:irc-social-network,
#         key:,
#         cs:language-and-connectivity,
#         cs:library,
#         cs:linked-data-notifications,
#         cs:linked-research,
#         cs:linked-research-decentralised-web,
#         cs:linked-research-decentralised-web.timemap,
#         cs:linked-research-scholarly-communication,
#         cs:linked-sdmx-data,
#         cs:linked-specifications-reports,
#         cs:linked-statistical-data-analysis,
#         cs:logo-identity-in-address-and-document-heading,
#         cs:lorem-ipsum,
#         medi:,
#         cs:microformats-introduction,
#         cs:microformats-misconceptions,
#         cs:mingling-of-the-lover-and-the-warrior,
#         cs:mirror-and-self,
#         cs:mobile-device-not-found,
#         cs:mu,
#         cs:my-responses-are-in-white,
#         cs:one-plus-one-equals-three-or-more,
#         cs:path-to-deri,
#         cs:philosophy-of-city-walking-and-life,
#         pre:,
#         cs:reaching-the-audience-part-1,
#         cs:robots.txt,
#         cs:rss,
#         scr:,
#         cs:sense-of-lsd-analysis,
#         cs:soliloquy-of-the-solipsist-by-sylvia-plath,
#         cs:souvenirs-from-lisbon,
#         cs:sparqlines-sparql-to-sparkline,
#         cs:statistical-linked-dataspaces,
#         cs:systems-and-choices,
#         cs:this-paper-is-a-demo,
#         cs:three-significant-modes-of-human-organisation-and-learning,
#         tmp:,
#         cs:tr-border-trick-for-ie,
#         cs:upgrades,
#         cs:volcanoes-with-fax-numbers,
#         cs:web-science-from-404-to-200,
#         cs:web-standards,
#         cs:web-typography,
#         cs:webmention,
#         cs:where-are-my-web-standards ;
#     stat:mtime 1675454887.411 ;
#     stat:size 12288 .
#
# cs:7 a html:Resource,
#         ldp:Resource ;
#     dct:modified "2022-09-15T09:26:38+00:00"^^xsd:dateTime ;
#     stat:mtime 1663233998.944 ;
#     stat:size 11094 .
#
# cs:about a html:Resource,
#         ldp:Resource ;
#     dct:modified "2022-07-04T12:01:13+00:00"^^xsd:dateTime ;
#     stat:mtime 1656936073.673 ;
#     stat:size 7807 .
#
# n0: a ldp:BasicContainer,
#         ldp:Container,
#         ldp:Resource ;
#     dct:modified "2021-03-07T12:28:03+00:00"^^xsd:dateTime ;
#     stat:mtime 1615120083.539 ;
#     stat:size 4096 .
#
# cs:atom a n1:Resource,
#         xm:Resource,
#         ldp:Resource ;
#     dct:modified "2021-05-21T16:55:25+00:00"^^xsd:dateTime,
#         "2021-08-10T04:57:25+00:00"^^xsd:dateTime ;
#     stat:mtime 1621616125.654,
#         1628571445.501 ;
#     stat:size 637927,
#         637929 .
#
# cs:call-for-linked-research a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.132 ;
#     stat:size 22354 .
#
# cs:communication-protocols a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-02-25T15:21:52+00:00"^^xsd:dateTime ;
#     stat:mtime 1614266512.974 ;
#     stat:size 11324 .
#
# cs:complexity-of-development-part-1 a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.132 ;
#     stat:size 15913 .
#
# cs:contacts a html:Resource,
#         ldp:Resource ;
#     dct:modified "2022-11-10T10:32:56+00:00"^^xsd:dateTime ;
#     stat:mtime 1668076376.485 ;
#     stat:size 6799 .
#
# cs:cooling-down-web-science a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.132 ;
#     stat:size 76123 .
#
# cs:css-background-order-and-w3c-specification-ambiguity-in-browsers a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.132 ;
#     stat:size 13592 .
#
# cs:css-specificity-and-selectors a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.136 ;
#     stat:size 21973 .
#
# cs:cv a html:Resource,
#         ldp:Resource ;
#     dct:modified "2023-02-03T20:07:49+00:00"^^xsd:dateTime ;
#     stat:mtime 1675454869.854 ;
#     stat:size 141728 .
#
# cs:dandelion-design a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.136 ;
#     stat:size 9893 .
#
# dok: a ldp:BasicContainer,
#         ldp:Container,
#         ldp:Resource ;
#     dct:modified "2023-01-23T10:13:23+00:00"^^xsd:dateTime ;
#     stat:mtime 1674468803.668 ;
#     stat:size 4096 .
#
# cs:dokieli a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.136 ;
#     stat:size 146303 .
#
# cs:dokieli-rww a html:Resource,
#         ldp:Resource ;
#     dct:modified "2020-08-13T07:30:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1597303812.721 ;
#     stat:size 80869 .
#
# cs:enabling-accessible-knowledge a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.136 ;
#     stat:size 124022 .
#
# cs:faipdaaf a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-02-25T15:18:03+00:00"^^xsd:dateTime ;
#     stat:mtime 1614266283.528 ;
#     stat:size 37050 .
#
# cs:favicon.ico a vnd:Resource,
#         ldp:Resource ;
#     dct:modified "2020-03-21T22:26:43+00:00"^^xsd:dateTime ;
#     stat:mtime 1584829603.849 ;
#     stat:size 894 .
#
# cs:five-months a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.136 ;
#     stat:size 12061 .
#
# cs:front-end-developer-integrator a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.136 ;
#     stat:size 18551 .
#
# cs:future-of-css-naked-day a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.136 ;
#     stat:size 26083 .
#
# cs:good-tips-and-customer-experience a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.136 ;
#     stat:size 17727 .
#
# cs:google-deutschland-stole-my-article a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.136 ;
#     stat:size 10931 .
#
# cs:googlebot-anchor-indexability-test a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.136 ;
#     stat:size 14654 .
#
# cs:googlef24ee8d5af3f254f.html a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-09-23T07:42:31+00:00"^^xsd:dateTime ;
#     stat:mtime 1632382951.713 ;
#     stat:size 53 .
#
# cs:hiding-email-addresses a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-02-25T15:19:31+00:00"^^xsd:dateTime ;
#     stat:mtime 1614266371.729 ;
#     stat:size 190398 .
#
# cs:how-to-create-a-linked-data-site a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-08-10T04:58:01+00:00"^^xsd:dateTime ;
#     stat:mtime 1628571481.161 ;
#     stat:size 70773 .
#
# cs:html-minimal-verbose a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.14 ;
#     stat:size 12713 .
#
# cs:html-overview a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.14 ;
#     stat:size 11251 .
#
# cs:human-language-and-html a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.14 ;
#     stat:size 12087 .
#
# cs:i-am-here-now a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-11-11T09:47:35+00:00"^^xsd:dateTime ;
#     stat:mtime 1636624055.716 ;
#     stat:size 4142 .
#
# cs:identical-tabindex-values-and-group-iterations a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.14 ;
#     stat:size 25403 .
#
# inbox: a ldp:BasicContainer,
#         ldp:Container,
#         ldp:Resource ;
#     dct:modified "2023-01-25T02:11:08+00:00"^^xsd:dateTime ;
#     stat:mtime 1674612668.181 ;
#     stat:size 4096 .
#
# cs:index.html a html:Resource,
#         ldp:Resource ;
#     dct:modified "2022-12-29T11:20:10+00:00"^^xsd:dateTime ;
#     stat:mtime 1672312810.25 ;
#     stat:size 7839 .
#
# cs:internal-seo-guidelines a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.14 ;
#     stat:size 28442 .
#
# cs:interview-with-steven-pemberton a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.14 ;
#     stat:size 12770 .
#
# cs:irc-social-network a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.14 ;
#     stat:size 21378 .
#
# key: a ldp:BasicContainer,
#         ldp:Container,
#         ldp:Resource ;
#     dct:modified "2020-11-09T12:06:07+00:00"^^xsd:dateTime ;
#     stat:mtime 1604923567.62 ;
#     stat:size 4096 .
#
# cs:language-and-connectivity a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.14 ;
#     stat:size 9102 .
#
# cs:library a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-12-15T09:37:11+00:00"^^xsd:dateTime ;
#     stat:mtime 1639561031.122 ;
#     stat:size 79848 .
#
# cs:linked-data-notifications a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-02-25T15:15:34+00:00"^^xsd:dateTime ;
#     stat:mtime 1614266134.835 ;
#     stat:size 127690 .
#
# cs:linked-research a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.14 ;
#     stat:size 43975 .
#
# cs:linked-research-decentralised-web a html:Resource,
#         ldp:Resource ;
#     dct:modified "2023-01-29T18:14:28+00:00"^^xsd:dateTime ;
#     stat:mtime 1675016068.578 ;
#     stat:size 1106096 .
#
# cs:linked-research-decentralised-web.timemap a tur:Resource,
#         ldp:Resource ;
#     dct:modified "2020-05-04T08:07:57+00:00"^^xsd:dateTime ;
#     stat:mtime 1588579677.274 ;
#     stat:size 453 .
#
# cs:linked-research-scholarly-communication a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-28T22:09:33+00:00"^^xsd:dateTime ;
#     stat:mtime 1574978973.415 ;
#     stat:size 138574 .
#
# cs:linked-sdmx-data a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.148 ;
#     stat:size 104738 .
#
# cs:linked-specifications-reports a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-02-25T15:15:18+00:00"^^xsd:dateTime ;
#     stat:mtime 1614266118.494 ;
#     stat:size 49070 .
#
# cs:linked-statistical-data-analysis a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-08-10T04:58:34+00:00"^^xsd:dateTime ;
#     stat:mtime 1628571514.889 ;
#     stat:size 117252 .
#
# cs:logo-identity-in-address-and-document-heading a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-02-25T15:20:53+00:00"^^xsd:dateTime ;
#     stat:mtime 1614266453.366 ;
#     stat:size 14818 .
#
# cs:lorem-ipsum a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-07-09T08:06:06+00:00"^^xsd:dateTime ;
#     stat:mtime 1625817966.669 ;
#     stat:size 6505 .
#
# medi: a ldp:BasicContainer,
#         ldp:Container,
#         ldp:Resource ;
#     dct:modified "2020-03-21T12:25:05+00:00"^^xsd:dateTime ;
#     stat:mtime 1584793505.194 ;
#     stat:size 4096 .
#
# cs:microformats-introduction a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.148 ;
#     stat:size 21520 .
#
# cs:microformats-misconceptions a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.148 ;
#     stat:size 21571 .
#
# cs:mingling-of-the-lover-and-the-warrior a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.148 ;
#     stat:size 9585 .
#
# cs:mirror-and-self a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-05-05T08:03:01+00:00"^^xsd:dateTime ;
#     stat:mtime 1620201781.38 ;
#     stat:size 3743 .
#
# cs:mobile-device-not-found a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.148 ;
#     stat:size 15629 .
#
# cs:mu a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-05-05T08:05:08+00:00"^^xsd:dateTime ;
#     stat:mtime 1620201908.753 ;
#     stat:size 5586 .
#
# cs:my-responses-are-in-white a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.148 ;
#     stat:size 21230 .
#
# cs:one-plus-one-equals-three-or-more a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-10-05T19:59:45+00:00"^^xsd:dateTime ;
#     stat:mtime 1633463985.306 ;
#     stat:size 9308 .
#
# cs:path-to-deri a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.148 ;
#     stat:size 16415 .
#
# cs:philosophy-of-city-walking-and-life a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.148 ;
#     stat:size 26149 .
#
# pre: a ldp:BasicContainer,
#         ldp:Container,
#         ldp:Resource ;
#     dct:modified "2022-05-07T12:12:29+00:00"^^xsd:dateTime ;
#     stat:mtime 1651925549.219 ;
#     stat:size 4096 .
#
# cs:reaching-the-audience-part-1 a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.152 ;
#     stat:size 23093 .
#
# cs:robots.txt a pl:Resource,
#         ldp:Resource ;
#     dct:modified "2021-09-23T07:41:07+00:00"^^xsd:dateTime ;
#     stat:mtime 1632382867.532 ;
#     stat:size 36 .
#
# cs:rss a xm:Resource,
#         ldp:Resource ;
#     dct:modified "2021-05-21T16:54:36+00:00"^^xsd:dateTime ;
#     stat:mtime 1621616076.445 ;
#     stat:size 637015 .
#
# scr: a ldp:BasicContainer,
#         ldp:Container,
#         ldp:Resource ;
#     dct:modified "2020-03-21T23:02:31+00:00"^^xsd:dateTime ;
#     stat:mtime 1584831751.372 ;
#     stat:size 4096 .
#
# cs:sense-of-lsd-analysis a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.152 ;
#     stat:size 75143 .
#
# cs:soliloquy-of-the-solipsist-by-sylvia-plath a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-10-22T08:29:58+00:00"^^xsd:dateTime ;
#     stat:mtime 1634891398.955 ;
#     stat:size 8867 .
#
# cs:souvenirs-from-lisbon a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-11-11T09:48:51+00:00"^^xsd:dateTime ;
#     stat:mtime 1636624131.2 ;
#     stat:size 18161 .
#
# cs:sparqlines-sparql-to-sparkline a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-05-21T16:58:07+00:00"^^xsd:dateTime ;
#     stat:mtime 1621616287.567 ;
#     stat:size 87648 .
#
# cs:statistical-linked-dataspaces a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-05-21T16:56:58+00:00"^^xsd:dateTime ;
#     stat:mtime 1621616218.566 ;
#     stat:size 199565 .
#
# cs:systems-and-choices a html:Resource,
#         ldp:Resource ;
#     dct:modified "2021-05-20T08:28:34+00:00"^^xsd:dateTime ;
#     stat:mtime 1621499314.828 ;
#     stat:size 11387 .
#
# cs:this-paper-is-a-demo a html:Resource,
#         ldp:Resource ;
#     dct:modified "2020-02-22T16:46:09+00:00"^^xsd:dateTime ;
#     stat:mtime 1582389969.608 ;
#     stat:size 41689 .
#
# cs:three-significant-modes-of-human-organisation-and-learning a html:Resource,
#         ldp:Resource ;
#     dct:modified "2022-09-15T09:32:22+00:00"^^xsd:dateTime ;
#     stat:mtime 1663234342.492 ;
#     stat:size 11497 .
#
# tmp: a ldp:BasicContainer,
#         ldp:Container,
#         ldp:Resource ;
#     dct:modified "2022-08-15T19:55:11+00:00"^^xsd:dateTime ;
#     stat:mtime 1660593311.092 ;
#     stat:size 4096 .
#
# cs:tr-border-trick-for-ie a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.152 ;
#     stat:size 69734 .
#
# cs:upgrades a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.152 ;
#     stat:size 13082 .
#
# cs:volcanoes-with-fax-numbers a html:Resource,
#         ldp:Resource ;
#     dct:modified "2022-07-01T12:16:04+00:00"^^xsd:dateTime ;
#     stat:mtime 1656677764.211 ;
#     stat:size 361567 .
#
# cs:web-science-from-404-to-200 a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.156 ;
#     stat:size 80096 .
#
# cs:web-standards a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.156 ;
#     stat:size 18827 .
#
# cs:web-typography a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.156 ;
#     stat:size 22396 .
#
# cs:webmention a html:Resource,
#         ldp:Resource ;
#     dct:modified "2020-06-03T09:16:48+00:00"^^xsd:dateTime ;
#     stat:mtime 1591175808.23 ;
#     stat:size 28490 .
#
# cs:where-are-my-web-standards a html:Resource,
#         ldp:Resource ;
#     dct:modified "2019-11-27T14:33:12+00:00"^^xsd:dateTime ;
#     stat:mtime 1574865192.156 ;
#     stat:size 43527 .

# %%
print_graph("./data/ingredients.rdf")
# Out:
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix ind: <http://purl.org/heals/ingredient/> .
# @prefix obo: <http://purl.obolibrary.org/obo/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix sm: <https://www.omg.org/techprocess/ab/SpecificationMetadata/> .
# @prefix wtm: <http://purl.org/heals/food/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ind:AlmondMeal a obo:FOODON_03400662,
#         obo:FOODON_03400685,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "almond meal" ;
#     dct:source "Wikipedia, \"Almond meal.\" [Online]. Available:https://en.wikipedia.org/wiki/Almond_meal. [Accessed: Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "25"^^xsd:nonNegativeInteger ;
#     skos:definition "an ingredient made from ground up almonds" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:AppleCiderVinegar a obo:FOODON_03400760,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "apple cider vinegar" ;
#     dct:source "Wikipedia, \"Apple cider vinegar.\" [Online]. Available: https://en.wikipedia.org/wiki/Apple_cider_vinegar. [Accessed: Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a vinegar made from fermented apple juice" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Bacon a obo:FOODON_03400667,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "bacon" ;
#     dct:source "Dictionary.com, \"bacon.\" [Online]. Available: https://www.dictionary.com/browse/bacon. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the back and sides of the hog, salted and dried or smoked, usually sliced thin and fried for food" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BakersYeast a wtm:Ingredient,
#         wtm:Yeast,
#         owl:NamedIndividual ;
#     rdfs:label "baker's yeast" ;
#     dct:source "Wikipedia, \"Baker's yeast.\" [Online]. Available: https://en.wikipedia.org/wiki/Baker%27s_yeast. [Accessed: Nov. 22, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "35"^^xsd:nonNegativeInteger ;
#     skos:definition "the strains of yeast commonly used as a leavening agent in baking bread and bakery products, where it converts the fermentable sugars present in the dough into carbon dioxide and ethanol" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BakingPowder a wtm:ChemicalFoodProduct,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "baking powder" ;
#     dct:source "\"Baking powder,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/baking%20powder. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a powder used as a leavening agent in making baked goods (such as quick breads) that typically consists of sodium bicarbonate, an acidic substance (such as cream of tartar), and starch or flour" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BakingSoda a wtm:ChemicalFoodProduct,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "baking soda" ;
#     dct:source "\"Baking soda,\" the free dictionary. [Online]. Available: https://www.thefreedictionary.com/baking+soda [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a white crystalline compound, NaHCO3, chemically known as sodium bicarbonate, that is used especially in beverages and as a leavening agent to make baked goods" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BalsamicVinegar a obo:FOODON_03400760,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "balsamic vinegar" ;
#     dct:source "\"Balsamic vinegar,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/balsamic%20vinegar. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "an aged Italian vinegar made from the must of white grapes" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Banana a obo:FOODON_03400673,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "banana" ;
#     dct:source "\"Banana ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/banana. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "55"^^xsd:nonNegativeInteger ;
#     skos:definition "an elongated usually tapering tropical fruit with soft pulpy flesh enclosed in a soft usually yellow rind" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Basil a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "basil" ;
#     dct:source "\"Basil,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/basil [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "the dried or fresh leaves of a basil used especially as a seasoning" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Beef a wtm:Ingredient,
#         wtm:MeatFromCow,
#         owl:NamedIndividual ;
#     rdfs:label "beef" ;
#     dct:source "\"Beef,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/beef. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the flesh of an adult domestic bovine used as food" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BeefBouillon a obo:FOODON_03400667,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "beef bouillon" ;
#     dct:source "EATBYDATE, \"Beef Broth Substitutes,\" 2012. [Online]. Available: https://www.eatbydate.com/substitutions/beef-broth-substitute/. [Accessed Oct. 27, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "an ingredient that can be combined with water to substitute for beef stock" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Bitter a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "bitter" ;
#     dct:source "\"Bitter,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/bitter. [Accessed: 18-Oct-2018]." ;
#     skos:definition "being or inducing the one of the four basic taste sensations that is peculiarly acrid acrid, astringent, or disagreeable and suggestive of an infusion of hops" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:BlackPepper a obo:FOODON_03400689,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "black pepper" ;
#     dct:source "\"Black Pepper,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/black pepper. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a spice that consists of the dried berry of an Indian vine ground with the black husk still on" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BlackPeppercorn a obo:FOODON_03400689,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "black peppercorn" ;
#     dct:source "\"Peppercorn ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/peppercorn. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a dried berry of the black pepper" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Blueberry a obo:FOODON_03400671,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "blueberry" ;
#     dct:source "Dictionary.com, \"blueberry.\" [Online]. Available: https://www.dictionary.com/browse/blueberry. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "25"^^xsd:nonNegativeInteger ;
#     skos:definition "the edible, usually bluish berry of various shrubs belonging to the genus Vaccinium, of the heath family" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BrownSugar a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "brown sugar" ;
#     dct:source "\"Brown Surgar,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/brown sugar. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "70"^^xsd:nonNegativeInteger ;
#     skos:definition "soft sugar whose crystals are covered by a film of refined dark syrup" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Butter a obo:FOODON_03400774,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "butter" ;
#     dct:source "\"Butter ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/butter. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a solid emulsion of fat globules, air, and water made by churning milk or cream and used as food" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Cabbage a obo:FOODON_03400675,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cabbage" ;
#     dct:source "\"Cabbage ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/cabbage. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "any of several brassicas of European origin especially a leafy garden plant with a short stem and a dense globular head of usually green leaves that is used as a vegetable" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CaneSugar a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cane sugar" ;
#     dct:source "Dictionary.com, \"cane sugar.\" [Online]. Available: https://www.dictionary.com/browse/cane-sugar. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "70"^^xsd:nonNegativeInteger ;
#     skos:definition "sugar obtained from sugar cane, identical with that obtained from the sugar beet" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CanolaOil a obo:FOODON_03400764,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "canola oil" ;
#     dct:source "Wikipedia, \"Canola oil.\" [Online]. Available: https://en.wikipedia.org/wiki/Canola_oil. [Accessed: Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a vegetable oil derived from a variety of rapeseed that is low in erucic acid" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Carrot a obo:FOODON_03400681,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "carrot" ;
#     dct:source "\"Carrot,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/carrot. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "a biennial herb with a usually orange spindle-shaped edible root" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Celsius a wtm:TemperatureMeasurement,
#         owl:NamedIndividual ;
#     rdfs:label "celsius" ;
#     dct:source "relating to, conforming to, or having the international thermometric scale on which the interval between the triple point of water and the boiling point of water is divided into 99.99 degrees with 0.01° representing the triple point and 100° the boiling point" ;
#     skos:definition "relating to, conforming to, or having the international thermometric scale on which the interval between the triple point of water and the boiling point of water is divided into 99.99 degrees with 0.01° representing the triple point and 100° the boiling point" ;
#     skos:editorialNote "A temperature scale that is used in recipes" ;
#     skos:scopeNote "value of temperature" .
#
# ind:ChayoteSquash a obo:FOODON_03400676,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "chayote squash" ;
#     dct:source "\"chayote,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/chayote. [Accessed: 1-Nov-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "50"^^xsd:nonNegativeInteger ;
#     skos:definition "pear-shaped fruit of a West Indian annual vine (Sechium edule) of the gourd family that is widely cultivated as a vegetable" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Cheese a obo:FOODON_03400775,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cheese" ;
#     dct:source "Dictionary.com, \"cheese.\" [Online]. Available: https://www.dictionary.com/browse/cheese. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the curd of milk separated from the whey and prepared in many ways as a food" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Chicken a wtm:Ingredient,
#         wtm:MeatFromChicken,
#         owl:NamedIndividual ;
#     rdfs:label "chicken" ;
#     dct:source "\"Chicken,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/chicken. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the common domestic fowl" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:ChickenBroth a obo:FOODON_03400667,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "chicken broth" ;
#     dct:source "vocabulary.com, \"chicken broth.\" [Online]. Available: https://www.vocabulary.com/dictionary/chicken%20broth. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a stock made with chicken" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:ChickenEgg a obo:FOODON_03400744,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "chicken egg" ;
#     dct:source "Dictionary.com, \"egg.\" [Online]. Available: https://www.dictionary.com/browse/egg. [Accessed Oct. 5, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the roundish reproductive body produced by a female chicken" ;
#     skos:editorialNote "Only used to refer to the egg of a chicken. Other types of eggs will appear under separate labels in the ontology." ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:ChuckRoast a wtm:Ingredient,
#         wtm:MeatFromCow,
#         owl:NamedIndividual ;
#     rdfs:label "chuck roast" ;
#     dct:source "\"Chuck steak,\" WIKIPEDIA [Online]. Available: https://en.wikipedia.org/wiki/Chuck_steak [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a cut of beef and is part of the sub primal cut known as the chuck" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Cilantro a obo:FOODON_03400678,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cilantro" ;
#     dct:source "Dictionary.com, \"cilantro.\" [Online]. Available: https://www.dictionary.com/browse/cilantro. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the strong-scented leaves of the coriander plant, used in salads or to flavor and garnish food" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Clove a obo:FOODON_03400674,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "clove" ;
#     dct:source "\"Clove,\" WIKIPEDIA [Online]. Available: https://en.wikipedia.org/wiki/Clove [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "the aromatic flower buds of a tree in the family Myrtaceae" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CocoaPowder a obo:FOODON_03400663,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cocoa powder" ;
#     dct:source "The Spruce Eats, \"What Is Cocoa Powder?,\"  2018.  [Online]. Available: https://www.thespruceeats.com/what-is-cocoa-powder-520351. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "20"^^xsd:nonNegativeInteger ;
#     skos:definition "an unsweetened powder produced by grinding the seeds of the fruit of a tropical evergreen tree called the cacao, or cocoa tree" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Coconut a obo:FOODON_03400670,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "coconut" ;
#     dct:source "Dictionary.com, \"coconut.\" [Online]. Available: https://www.dictionary.com/browse/coconut. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "35"^^xsd:nonNegativeInteger ;
#     skos:definition "the large, hard-shelled seed of the coconut palm, lined with a white edible meat, and containing a milky liquid" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CoconutMilk a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "coconut milk" ;
#     dct:source "Dictionary.com, \"coconut milk.\" [Online]. Available: https://www.dictionary.com/browse/coconut-milk. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "40"^^xsd:nonNegativeInteger ;
#     skos:definition "the clear, potable liquid contained within the young hollow seed of the coconut palm" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CornSyrup a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "corn syrup" ;
#     dct:source "Dictionary.com, \"corn syrup.\"  [Online]. Available: https://www.dictionary.com/browse/corn-syrup. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "115"^^xsd:nonNegativeInteger ;
#     skos:definition "syrup prepared from corn" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CornedBeef a obo:FOODON_03400667,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "corned beef" ;
#     dct:source "\"Corned beef ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/corned beef. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "beef that has been preserved in salt water" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Cornstarch a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cornstarch" ;
#     dct:source "\"Cornstarch ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/cornstarch. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGlycemicIndex false,
#         "95"^^xsd:nonNegativeInteger ;
#     skos:definition "starch made from corn and used in foods as a thickening agent, in making corn syrup and sugars, and in the manufacture of adhesives and sizes for paper and textiles" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CowMilk a wtm:Ingredient,
#         wtm:MilkFromCow,
#         owl:NamedIndividual ;
#     rdfs:label "cow milk" ;
#     dct:source "Wikipedia, \"Milk.\" [Online]. Available: https://en.wikipedia.org/wiki/Milk#Cow's_milk. [Accessed: Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "30"^^xsd:nonNegativeInteger ;
#     skos:definition "milk obtained from a cow" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Creamy a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "creamy" ;
#     dct:source "\"Creamy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/creamy. [Accessed: 18-Oct-2018]." ;
#     skos:definition "resembling cream (as in color, texture, or taste)" ;
#     skos:scopeNote "used as a texture" .
#
# ind:Crumbly a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "crumbly" ;
#     dct:source "\"Crumbly,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/crumbly. [Accessed: 18-Oct-2018]." ;
#     skos:definition "easily crumbled" ;
#     skos:scopeNote "used as a texture" .
#
# ind:DriedCranberry a obo:FOODON_03400756,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "dried cranberry" ;
#     dct:source "Wikipedia, \"Dried cranberry.\" [Online]. Available: https://en.wikipedia.org/wiki/Dried_cranberry. [Accessed: Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "30"^^xsd:nonNegativeInteger ;
#     skos:definition "an ingredient made by partially dehydrating fresh cranberries" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Fahrenheit a wtm:TemperatureMeasurement,
#         owl:NamedIndividual ;
#     rdfs:label "fahrenheit" ;
#     dct:source "\"Fahrenheit,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/Fahrenheit. [Accessed: 12-Oct-2018]." ;
#     skos:definition "relating or conforming to a thermometric scale on which under standard atmospheric pressure the boiling point of water is at 212 degrees above the zero of the scale, the freezing point is at 32 degrees above zero, and the zero point approximates the temperature produced by mixing equal quantities by weight of snow and common salt" ;
#     skos:editorialNote "A temperature scale that is used in recipes" ;
#     skos:scopeNote "value of temperature" .
#
# ind:Garlic a obo:FOODON_03400674,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "garlic" ;
#     dct:source "\"Garlic ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/garlic. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "30"^^xsd:nonNegativeInteger ;
#     skos:definition "widely cultivated for its pungent compound bulbs much used in cookery" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:GlutenFreeFlour a obo:FOODON_03400759,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "gluten free flour" ;
#     dct:source "Baking Bites, \"What is Gluten Free Flour?\"[Online]. Available: http://bakingbites.com/2013/01/what-is-gluten-free-flour/. [Accessed Nov. 1, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "95"^^xsd:nonNegativeInteger ;
#     wtm:substitutesFor ind:AllPurposeFlour ;
#     skos:definition "flours that are made of non-gluten containing products" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Gooey a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "gooey" ;
#     dct:source "\"Gooey,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/gooey. [Accessed: 18-Oct-2018]." ;
#     skos:definition "a viscid or sticky substance" ;
#     skos:scopeNote "used as a texture" .
#
# ind:Greasy a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "greasy" ;
#     dct:source "\"Greasy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/greasy. [Accessed: 18-Oct-2018]." ;
#     skos:definition "containing an unusual amount of grease" ;
#     skos:scopeNote "used as a texture" .
#
# ind:GreenOnion a obo:FOODON_03400674,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "green onion" ;
#     dct:source "Dictionary.com, \"green onion.\" [Online]. Available: https://www.dictionary.com/browse/green-onion. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "a young onion with a slender green stalk and a small bulb, used as a table vegetable, usually raw,especially in salads; scallion" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:GreenPepper a obo:FOODON_03400677,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "green pepper" ;
#     dct:source "Dictionary.com, \"green pepper.\" [Online]. Available: https://www.dictionary.com/browse/green-pepper. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "the mild-flavored, unripe fruit of the bell or sweet pepper, Capsicum annuum grossum, used as a greenvegetable" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Honey a obo:FOODON_03400666,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "honey" ;
#     dct:source "\"Honey,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/honey. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "60"^^xsd:nonNegativeInteger ;
#     skos:definition "a sweet viscid material elaborated out of the nectar of flowers in the honey sac of various bees" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Hour a wtm:TimeMeasurement,
#         owl:NamedIndividual ;
#     rdfs:label "hour" ;
#     dct:source "Dictionary.com, \"hour.\" [Online]. Available: https://www.dictionary.com/browse/hour. [Accessed Oct. 5, 2018]" ;
#     skos:altLabel "hours" ;
#     skos:definition "the measured or measurable period during which an action, process, or condition exists or continues" ;
#     skos:scopeNote "value of time" .
#
# ind:Kamut a obo:FOODON_03400683,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "kamut" ;
#     dct:source "Kamut, \"The grain,\" 2018. [Online]. Available: https://www.kamut.com/en/discover/the-grain. [Accessed Oct. 20, 2018]" ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "45"^^xsd:nonNegativeInteger ;
#     skos:definition "khorasan wheat (kamut) is an ancient grain" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:KamutFlour a obo:FOODON_03400759,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "kamut flour" ;
#     dct:source "foodrepublic.com, \"What Is Kamut?\" [Online]. Available: http://www.foodrepublic.com/2013/04/15/what-is-kamut/. [Accessed Nov.9, 2018]" ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "45"^^xsd:nonNegativeInteger ;
#     wtm:substitutesFor ind:AllPurposeFlour ;
#     skos:definition "flour made from an ancient grain also known as khorsan wheat" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Lamb a wtm:Ingredient,
#         wtm:MeatFromLamb,
#         owl:NamedIndividual ;
#     rdfs:label "lamb" ;
#     dct:source "\"Lamb,\" WIKIPEDIA [Online]. Available: https://en.wikipedia.org/wiki/Lamb [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the meat of sheep" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:LemonJuice a obo:FOODON_03400766,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "lemon juice" ;
#     dct:source "\"lemon juice,\" the free dictionary. [Online]. Available: https://www.thefreedictionary.com/lemon+juice. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "20"^^xsd:nonNegativeInteger ;
#     skos:definition "usually freshly squeezed juice of lemons" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Mayonnaise a obo:FOODON_03400776,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "mayonnaise" ;
#     dct:source "Dictionary.com, \"mayonnaise.\" [Online]. Available: https://www.dictionary.com/browse/mayonnaise. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "60"^^xsd:nonNegativeInteger ;
#     skos:definition "a thick dressing of egg yolks, vinegar or lemon juice, oil, and seasonings, used for salads, sandwiches,vegetable dishes, etc" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Minute a wtm:TimeMeasurement,
#         owl:NamedIndividual ;
#     rdfs:label "minute" ;
#     dct:source "Dictionary.com, \"minute.\" [Online]. Available: https://www.dictionary.com/browse/minute?s=t. [Accessed Oct. 5, 2018]" ;
#     skos:altLabel "minutes" ;
#     skos:definition "the sixtieth part (1/60) of an hour; sixty seconds" ;
#     skos:scopeNote "value of time" .
#
# ind:Moist a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "moist" ;
#     dct:source "\"Moist,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/moist. [Accessed: 18-Oct-2018]." ;
#     skos:definition "slightly or moderately wet" ;
#     skos:scopeNote "used as a texture" .
#
# ind:Mushy a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "mushy" ;
#     dct:source "\"Mushy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/mushy. [Accessed: 18-Oct-2018]." ;
#     skos:definition "having the consistency of mush" ;
#     skos:scopeNote "used as a texture" .
#
# ind:Nutty a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "nutty" ;
#     dct:source "\"Nutty,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/nutty. [Accessed: 12-Oct-2018]." ;
#     skos:definition "having a flavor like that of nuts" ;
#     skos:editorialNote "A property of flavor that will aid in the substitution decision making of the ontology" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:Oat a obo:FOODON_03400683,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "oat" ;
#     dct:source "Dictionary.com, \"oat.\" [Online]. Available: https://www.dictionary.com/browse/oat. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "40"^^xsd:nonNegativeInteger ;
#     skos:definition "a cereal grass, Avena sativa, cultivated for its edible seed" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:OliveOil a obo:FOODON_03400764,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "olive oil" ;
#     dct:source "\"Olive oil,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/olive%20oil. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a pale yellow to yellowish-green nondrying oil that is obtained from olives, is high in monounsaturated fat, and is used chiefly as a salad oil and in cooking" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Oregano a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "oregano" ;
#     dct:source "\"Oregano,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/oregano [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a bushy perennial mint (Origanum vulgare) with leaves that are used as a seasoning and a source of aromatic oil" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Paprika a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "paprika" ;
#     dct:source "\"Paprika ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/paprika. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "a usually mild red condiment consisting of the dried finely ground pods of various sweet peppers" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Parsley a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "parsley" ;
#     dct:source "\"Parsley ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/parsley. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a European biennial herb of the carrot family widely grown for its finely dissected curly or flat leaves which are used as an herb or garnish" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Peanut a obo:FOODON_03400686,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "peanut" ;
#     dct:source "Dictionary.com, \"peanut.\" [Online]. Available: https://www.dictionary.com/browse/peanut. [Accessed Oct. 5, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "the pod or the enclosed edible seed of the plant, Arachis hypogaea, of the legume family: the pod is forced underground in growing, where it ripens" ;
#     skos:editorialNote "This definition refers to the nuts of the plant as used as an ingredient in a recipe." ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Potato a obo:FOODON_03400681,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "potato" ;
#     dct:source "\"Potato,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/potato. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "70"^^xsd:nonNegativeInteger ;
#     skos:definition "a memeber of the nightshade family widely cultivated for its edible starchy tuber" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Rosemary a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "rosemary" ;
#     dct:source "\"Rosemary ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/rosemary. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a fragrant shrubby Mediterranean mint having grayish-green needlelike leaves used as a seasoning" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Salt a wtm:ChemicalFoodProduct,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "salt" ;
#     dct:source "\"Salt,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/salt. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a crystalline compound NaCl that consists of sodium chloride, is abundant in nature, and is used especially to season or preserve food or in industry" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Salty a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "salty" ;
#     dct:source "\"Salty,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/salty. [Accessed: 18-Oct-2018]." ;
#     skos:definition "of, seasoned with, or containing salt" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:SesameOil a obo:FOODON_03400764,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "sesame oil" ;
#     dct:source "Dictionary.com, \"sesame oil.\" [Online]. Available: https://www.dictionary.com/browse/sesame-oil. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a yellow oil expressed from the seeds of the sesame, used in cooking, as a vehicle for medicines, and in the manufacture of margarine, soap, and cosmetics" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Smoky a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "smoky" ;
#     dct:source "\"Smoky,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/smoky. [Accessed: 18-Oct-2018]." ;
#     skos:definition "suggestive of smoke especially in flavor or odor" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:SoySauce a obo:FOODON_03400663,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "soy sauce" ;
#     dct:source "Dictionary.com, \"soy sauce.\" [Online]. Available: https://www.dictionary.com/browse/soy-sauce. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a salty, fermented sauce prepared from soybeans, used in East Asian cuisine" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Spicy a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "spicy" ;
#     dct:source "\"Spicy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/spicy. [Accessed: 18-Oct-2018]." ;
#     skos:definition "having the quality, flavor, or fragrance of spice" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:Sweet a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "sweet" ;
#     dct:source "\"Sweet,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/sweet. [Accessed: 18-Oct-2018]." ;
#     skos:definition "being or inducing the one of the four basic taste sensations that is typically induced by disaccharides and is mediated especially by receptors in taste buds at the front of the tongue" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:TapiocaFlour a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "tapioca flour" ;
#     dct:source "\"Tapioca,\" The Free Dictionary. [Online]. Available: https://www.thefreedictionary.com/Tapioca+flour. [Accessed Nov.9, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "85"^^xsd:nonNegativeInteger ;
#     skos:definition "a flour made from the tapioca plant" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Tarragon a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "tarragon" ;
#     dct:source "\"Tarragon ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tarragon. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a small widely cultivated perennial artemisia (Artemisia dracunculus) having aromatic narrow usually entire leaves, its leaves used as a seasoning" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Tart a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "tart" ;
#     dct:source "\"Tart,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tart. [Accessed: 18-Oct-2018]." ;
#     skos:definition "agreeably sharp or acid to the taste" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:Thyme a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "thyme" ;
#     dct:source "\"Thyme,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/thyme. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "any of a genus (Thymus) of Eurasian mints with small pungent aromatic leaves" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Tomato a obo:FOODON_03400677,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "tomato" ;
#     dct:source "\"Tomato,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tomato. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "30"^^xsd:nonNegativeInteger ;
#     skos:definition "the usually large, rounded, edible, pulpy berry of an herb (genus Solanum) of the nightshade family native to South America that is typically red but may be yellow, orange, green, or purplish in color and is eaten raw or cooked as a vegetable" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:User15 a wtm:User,
#         owl:NamedIndividual ;
#     rdfs:label "user 15" ;
#     dct:source "Techopedia, \"User Identification (User ID),\" 2018. [Online]. Available: https://www.techopedia.com/definition/12552/user-identification-user-id. [Accessed Oct. 18, 2018]" ;
#     wtm:dislikes ind:Almond,
#         ind:Celery ;
#     wtm:forbids ind:Onion ;
#     wtm:isAllergicTo ind:Pecan ;
#     skos:definition "the user with ID 15" ;
#     skos:scopeNote "represents an individual user" .
#
# ind:VanillaExtract a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "vanilla extract" ;
#     dct:source "Wikipedia, \"Vanilla extract.\" [Online]. Available: https://en.wikipedia.org/wiki/Vanilla_extract. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a solution made by macerating and percolating vanilla pods in a solution of ethanol and water" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:VegetableOil a obo:FOODON_03400764,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "vegetable oil" ;
#     dct:source "\"Vegetable Oil ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/vegetable oil. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "an oil of plant origin" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Water a wtm:ChemicalFoodProduct,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "water" ;
#     dct:source "\"Water ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/water. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the liquid that descends from the clouds as rain, forms streams, lakes, and seas, and is a major constituent of all living matter and that when pure is an odorless, tasteless, very slightly compressible liquid oxide of hydrogen H2O which appears bluish in thick layers, freezes at 0° C and boils at 100° C, has a maximum density at 4° C and a high specific heat, is feebly ionized to hydrogen and hydroxyl ions, and is a poor conductor of electricity and a good solvent" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:WhiteSugar a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "white sugar" ;
#     dct:source "\"Sugar,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/sugar. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "70"^^xsd:nonNegativeInteger ;
#     skos:definition "a sweet crystallizable material that consists wholly or essentially of sucrose, is colorless or white when pure tending to brown when less refined, is obtained commercially from sugarcane or sugar beet and less extensively from sorghum, maples, and palms, and is important as a source of dietary carbohydrate and as a sweetener and preservative of other foods" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:WhiteVinegar a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "white vinegar" ;
#     dct:source "Dictionary.com, \"vinegar.\" [Online]. Available: https://www.dictionary.com/browse/vinegar. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a sour liquid consisting of dilute and impure acetic acid" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:WholeGrainMustard a obo:FOODON_03400663,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "whole grain mustard" ;
#     dct:source "TasteofHome, \"What Is Whole Grain Mustard?,\" 2018. [Online]. Available: https://www.tasteofhome.com/cooking-tips/ask-the-test-kitchen/what-is-whole-grain-mustard-. [Accessed Oct. 27 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "55"^^xsd:nonNegativeInteger ;
#     skos:definition "prepared mustard with visible mustard seeds" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:WholeWheatFlour a obo:FOODON_03400759,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "whole wheat flour" ;
#     dct:source "\"Whole Wheat Flour ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/whole wheat flour. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "40"^^xsd:nonNegativeInteger ;
#     wtm:substitutesFor ind:AllPurposeFlour ;
#     skos:definition "flour that is ground from the whole grain and contains all the constituents of the wheat kernels" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind: a owl:Ontology ;
#     rdfs:label "What to Make Individuals" ;
#     dct:abstract "The WhatToMake Individuals Ontology contains the invididual recipes and food items used in those recipes that are available in the system. These individuals are defined using classes and properties that are defined in the WhatToMake Base Ontology."^^xsd:string ;
#     dct:contributor "Forest Eckhardt",
#         "Kevin Blissett",
#         "Miao Qi",
#         "Yarden Ne'eman" ;
#     dct:description "The goal of this project is to create a system capable of recommending recipes to a user subject to the ingredients that user has on hand and the time they want to spend cooking. The system should also be able to recommend best-matched substitutions for ingredients where appropriate in order to meet the user’s taste preferences or food allergy related needs. The users are allowed to specify the meal types (e.g. lunch) and course types (e.g. entree) in the request. If the users request not to have recipes that contain high Glycemic Index (GI) ingredients, the system will avoid offering these high glycemic recipes in the recommendations." ;
#     dct:license "http://opensource.org/licenses/MIT"^^xsd:anyURI ;
#     dct:modified "2019-04-12"^^xsd:date ;
#     dct:publisher "WhatToMake" ;
#     dct:references "https://tw.rpi.edu/web/Courses/Ontologies/2018/Project2/maintenance" ;
#     owl:imports wtm:,
#         <http://www.omg.org/techprocess/ab/SpecificationMetadata/> ;
#     owl:priorVersion "https://tw.rpi.edu/Courses/Ontologies/2018/WhatToMake/WhatToMake_Individuals/" ;
#     owl:versionIRI ind: ;
#     skos:changeNote "Changes to this ontology since the previous version include: update of ontology IRI" ;
#     sm:copyright "Copyright (c) 2018 Kevin Blissett, Forest Eckhardt, Yarden Ne'eman, Miao Qi" .
#
# ind:Celery a obo:FOODON_03400682,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "celery" ;
#     dct:source "\"Celery ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/celery. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "a European herb the carrot family specifically one of a cultivated variety with leafstalks eaten raw or cooked" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Onion a obo:FOODON_03400674,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "onion" ;
#     dct:source "\"Onion ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/onion. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "a widely cultivated Asian herb of the lily family with pungent edible bulbs" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:PumpkinSeed a obo:FOODON_03400686,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "pumpkin seed" ;
#     dct:source "\"pumpkin seed - Dictionary Definition,\" Vocabulary.com. [Online]. Available: https://www.vocabulary.com/dictionary/pumpkin seed. [Accessed: 12-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "10"^^xsd:nonNegativeInteger ;
#     wtm:substitutesFor ind:Walnut ;
#     skos:definition "the edible seed of a pumpkin" ;
#     skos:editorialNote "A potential substitution for members of the tree nut family" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:AllPurposeFlour a obo:FOODON_03400759,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "all purpose flour" ;
#     dct:source "\"Flour,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/flour. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "71"^^xsd:nonNegativeInteger ;
#     skos:definition "a product consisting of finely milled wheat" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Almond a obo:FOODON_03400685,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "almond" ;
#     dct:source "Dictionary.com, \"almond.\" [Online]. Available: https://www.dictionary.com/browse/almond. [Accessed Oct. 20, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     wtm:hasTexture ind:Crunchy ;
#     wtm:substitutesFor ind:Pecan,
#         ind:PumpkinSeed,
#         ind:Walnut ;
#     skos:definition "the nutlike kernel of the fruit of either of two trees, Prunus dulcis (sweet almond) or P. dulcis amara (bitter almond), which grow in warm temperate regions" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Crunchy a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "crunchy" ;
#     dct:source "\"Crunchy,\" Dictionary.com. [Online]. Available: https://www.dictionary.com/browse/crunchy?s=t. [Accessed: 12-Oct-2018]." ;
#     skos:definition "crisp, brittle" ;
#     skos:editorialNote "This is a subclass of texture and is one of the textural components that could be considered for substitutions" ;
#     skos:scopeNote "used as a texture" .
#
# ind:Pecan a obo:FOODON_03400685,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "pecan" ;
#     dct:source "Dictionary.com, \"pecan.\" [Online]. Available: https://www.dictionary.com/browse/pecan. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     wtm:hasTexture ind:Crunchy ;
#     wtm:substitutesFor ind:Almond,
#         ind:Walnut ;
#     skos:definition "a tall hickory tree, Carya illinoinensis, of the southern U.S. and Mexico, cultivated for its oval, smooth-shelled, edible nuts" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Walnut a obo:FOODON_03400685,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "walnut" ;
#     dct:source "\"Walnut,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/walnut. [Accessed: 12-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     wtm:hasTexture ind:Crunchy ;
#     wtm:substitutesFor ind:Almond,
#         ind:Pecan,
#         ind:PumpkinSeed ;
#     skos:definition "the furrowed nut of any of a genus (Juglans of the family Juglandaceae, the walnut family) of deciduous trees" ;
#     skos:editorialNote "Member of the tree nut family which is a common allergen" ;
#     skos:scopeNote "used as an ingredient" .

# %% [markdown]
# ## Serialising and saving RDF graphs
#
# There are different formats for storing RDF triples. Semantically, these mean the same, they differ only in their syntax.
#
#
# Use the function Graph.serialize(format).
#
# **Exercise 2**
#
# 1. serialise one of the graphs to the .ttl, .xml and .nt format, and print the first n lines to compare the syntax
# 1. save your graph in the turtle format to the ./data/ folder

# %%
#serialize the chosen graph
def serialize_graph(loc, f):

    g = Graph()

    g.parse(loc)

    print(g.serialize(format=f))


serialize_graph("./data/ingredients.rdf", 'ttl')
# Out:
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix ind: <http://purl.org/heals/ingredient/> .
# @prefix obo: <http://purl.obolibrary.org/obo/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix sm: <https://www.omg.org/techprocess/ab/SpecificationMetadata/> .
# @prefix wtm: <http://purl.org/heals/food/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ind:AlmondMeal a obo:FOODON_03400662,
#         obo:FOODON_03400685,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "almond meal" ;
#     dct:source "Wikipedia, \"Almond meal.\" [Online]. Available:https://en.wikipedia.org/wiki/Almond_meal. [Accessed: Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "25"^^xsd:nonNegativeInteger ;
#     skos:definition "an ingredient made from ground up almonds" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:AppleCiderVinegar a obo:FOODON_03400760,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "apple cider vinegar" ;
#     dct:source "Wikipedia, \"Apple cider vinegar.\" [Online]. Available: https://en.wikipedia.org/wiki/Apple_cider_vinegar. [Accessed: Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a vinegar made from fermented apple juice" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Bacon a obo:FOODON_03400667,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "bacon" ;
#     dct:source "Dictionary.com, \"bacon.\" [Online]. Available: https://www.dictionary.com/browse/bacon. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the back and sides of the hog, salted and dried or smoked, usually sliced thin and fried for food" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BakersYeast a wtm:Ingredient,
#         wtm:Yeast,
#         owl:NamedIndividual ;
#     rdfs:label "baker's yeast" ;
#     dct:source "Wikipedia, \"Baker's yeast.\" [Online]. Available: https://en.wikipedia.org/wiki/Baker%27s_yeast. [Accessed: Nov. 22, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "35"^^xsd:nonNegativeInteger ;
#     skos:definition "the strains of yeast commonly used as a leavening agent in baking bread and bakery products, where it converts the fermentable sugars present in the dough into carbon dioxide and ethanol" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BakingPowder a wtm:ChemicalFoodProduct,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "baking powder" ;
#     dct:source "\"Baking powder,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/baking%20powder. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a powder used as a leavening agent in making baked goods (such as quick breads) that typically consists of sodium bicarbonate, an acidic substance (such as cream of tartar), and starch or flour" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BakingSoda a wtm:ChemicalFoodProduct,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "baking soda" ;
#     dct:source "\"Baking soda,\" the free dictionary. [Online]. Available: https://www.thefreedictionary.com/baking+soda [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a white crystalline compound, NaHCO3, chemically known as sodium bicarbonate, that is used especially in beverages and as a leavening agent to make baked goods" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BalsamicVinegar a obo:FOODON_03400760,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "balsamic vinegar" ;
#     dct:source "\"Balsamic vinegar,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/balsamic%20vinegar. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "an aged Italian vinegar made from the must of white grapes" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Banana a obo:FOODON_03400673,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "banana" ;
#     dct:source "\"Banana ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/banana. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "55"^^xsd:nonNegativeInteger ;
#     skos:definition "an elongated usually tapering tropical fruit with soft pulpy flesh enclosed in a soft usually yellow rind" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Basil a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "basil" ;
#     dct:source "\"Basil,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/basil [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "the dried or fresh leaves of a basil used especially as a seasoning" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Beef a wtm:Ingredient,
#         wtm:MeatFromCow,
#         owl:NamedIndividual ;
#     rdfs:label "beef" ;
#     dct:source "\"Beef,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/beef. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the flesh of an adult domestic bovine used as food" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BeefBouillon a obo:FOODON_03400667,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "beef bouillon" ;
#     dct:source "EATBYDATE, \"Beef Broth Substitutes,\" 2012. [Online]. Available: https://www.eatbydate.com/substitutions/beef-broth-substitute/. [Accessed Oct. 27, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "an ingredient that can be combined with water to substitute for beef stock" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Bitter a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "bitter" ;
#     dct:source "\"Bitter,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/bitter. [Accessed: 18-Oct-2018]." ;
#     skos:definition "being or inducing the one of the four basic taste sensations that is peculiarly acrid acrid, astringent, or disagreeable and suggestive of an infusion of hops" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:BlackPepper a obo:FOODON_03400689,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "black pepper" ;
#     dct:source "\"Black Pepper,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/black pepper. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a spice that consists of the dried berry of an Indian vine ground with the black husk still on" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BlackPeppercorn a obo:FOODON_03400689,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "black peppercorn" ;
#     dct:source "\"Peppercorn ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/peppercorn. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a dried berry of the black pepper" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Blueberry a obo:FOODON_03400671,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "blueberry" ;
#     dct:source "Dictionary.com, \"blueberry.\" [Online]. Available: https://www.dictionary.com/browse/blueberry. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "25"^^xsd:nonNegativeInteger ;
#     skos:definition "the edible, usually bluish berry of various shrubs belonging to the genus Vaccinium, of the heath family" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:BrownSugar a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "brown sugar" ;
#     dct:source "\"Brown Surgar,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/brown sugar. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "70"^^xsd:nonNegativeInteger ;
#     skos:definition "soft sugar whose crystals are covered by a film of refined dark syrup" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Butter a obo:FOODON_03400774,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "butter" ;
#     dct:source "\"Butter ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/butter. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a solid emulsion of fat globules, air, and water made by churning milk or cream and used as food" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Cabbage a obo:FOODON_03400675,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cabbage" ;
#     dct:source "\"Cabbage ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/cabbage. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "any of several brassicas of European origin especially a leafy garden plant with a short stem and a dense globular head of usually green leaves that is used as a vegetable" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CaneSugar a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cane sugar" ;
#     dct:source "Dictionary.com, \"cane sugar.\" [Online]. Available: https://www.dictionary.com/browse/cane-sugar. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "70"^^xsd:nonNegativeInteger ;
#     skos:definition "sugar obtained from sugar cane, identical with that obtained from the sugar beet" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CanolaOil a obo:FOODON_03400764,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "canola oil" ;
#     dct:source "Wikipedia, \"Canola oil.\" [Online]. Available: https://en.wikipedia.org/wiki/Canola_oil. [Accessed: Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a vegetable oil derived from a variety of rapeseed that is low in erucic acid" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Carrot a obo:FOODON_03400681,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "carrot" ;
#     dct:source "\"Carrot,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/carrot. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "a biennial herb with a usually orange spindle-shaped edible root" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Celsius a wtm:TemperatureMeasurement,
#         owl:NamedIndividual ;
#     rdfs:label "celsius" ;
#     dct:source "relating to, conforming to, or having the international thermometric scale on which the interval between the triple point of water and the boiling point of water is divided into 99.99 degrees with 0.01° representing the triple point and 100° the boiling point" ;
#     skos:definition "relating to, conforming to, or having the international thermometric scale on which the interval between the triple point of water and the boiling point of water is divided into 99.99 degrees with 0.01° representing the triple point and 100° the boiling point" ;
#     skos:editorialNote "A temperature scale that is used in recipes" ;
#     skos:scopeNote "value of temperature" .
#
# ind:ChayoteSquash a obo:FOODON_03400676,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "chayote squash" ;
#     dct:source "\"chayote,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/chayote. [Accessed: 1-Nov-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "50"^^xsd:nonNegativeInteger ;
#     skos:definition "pear-shaped fruit of a West Indian annual vine (Sechium edule) of the gourd family that is widely cultivated as a vegetable" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Cheese a obo:FOODON_03400775,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cheese" ;
#     dct:source "Dictionary.com, \"cheese.\" [Online]. Available: https://www.dictionary.com/browse/cheese. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the curd of milk separated from the whey and prepared in many ways as a food" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Chicken a wtm:Ingredient,
#         wtm:MeatFromChicken,
#         owl:NamedIndividual ;
#     rdfs:label "chicken" ;
#     dct:source "\"Chicken,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/chicken. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the common domestic fowl" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:ChickenBroth a obo:FOODON_03400667,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "chicken broth" ;
#     dct:source "vocabulary.com, \"chicken broth.\" [Online]. Available: https://www.vocabulary.com/dictionary/chicken%20broth. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a stock made with chicken" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:ChickenEgg a obo:FOODON_03400744,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "chicken egg" ;
#     dct:source "Dictionary.com, \"egg.\" [Online]. Available: https://www.dictionary.com/browse/egg. [Accessed Oct. 5, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the roundish reproductive body produced by a female chicken" ;
#     skos:editorialNote "Only used to refer to the egg of a chicken. Other types of eggs will appear under separate labels in the ontology." ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:ChuckRoast a wtm:Ingredient,
#         wtm:MeatFromCow,
#         owl:NamedIndividual ;
#     rdfs:label "chuck roast" ;
#     dct:source "\"Chuck steak,\" WIKIPEDIA [Online]. Available: https://en.wikipedia.org/wiki/Chuck_steak [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a cut of beef and is part of the sub primal cut known as the chuck" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Cilantro a obo:FOODON_03400678,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cilantro" ;
#     dct:source "Dictionary.com, \"cilantro.\" [Online]. Available: https://www.dictionary.com/browse/cilantro. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the strong-scented leaves of the coriander plant, used in salads or to flavor and garnish food" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Clove a obo:FOODON_03400674,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "clove" ;
#     dct:source "\"Clove,\" WIKIPEDIA [Online]. Available: https://en.wikipedia.org/wiki/Clove [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "the aromatic flower buds of a tree in the family Myrtaceae" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CocoaPowder a obo:FOODON_03400663,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cocoa powder" ;
#     dct:source "The Spruce Eats, \"What Is Cocoa Powder?,\"  2018.  [Online]. Available: https://www.thespruceeats.com/what-is-cocoa-powder-520351. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "20"^^xsd:nonNegativeInteger ;
#     skos:definition "an unsweetened powder produced by grinding the seeds of the fruit of a tropical evergreen tree called the cacao, or cocoa tree" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Coconut a obo:FOODON_03400670,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "coconut" ;
#     dct:source "Dictionary.com, \"coconut.\" [Online]. Available: https://www.dictionary.com/browse/coconut. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "35"^^xsd:nonNegativeInteger ;
#     skos:definition "the large, hard-shelled seed of the coconut palm, lined with a white edible meat, and containing a milky liquid" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CoconutMilk a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "coconut milk" ;
#     dct:source "Dictionary.com, \"coconut milk.\" [Online]. Available: https://www.dictionary.com/browse/coconut-milk. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "40"^^xsd:nonNegativeInteger ;
#     skos:definition "the clear, potable liquid contained within the young hollow seed of the coconut palm" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CornSyrup a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "corn syrup" ;
#     dct:source "Dictionary.com, \"corn syrup.\"  [Online]. Available: https://www.dictionary.com/browse/corn-syrup. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "115"^^xsd:nonNegativeInteger ;
#     skos:definition "syrup prepared from corn" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CornedBeef a obo:FOODON_03400667,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "corned beef" ;
#     dct:source "\"Corned beef ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/corned beef. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "beef that has been preserved in salt water" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Cornstarch a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "cornstarch" ;
#     dct:source "\"Cornstarch ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/cornstarch. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGlycemicIndex false,
#         "95"^^xsd:nonNegativeInteger ;
#     skos:definition "starch made from corn and used in foods as a thickening agent, in making corn syrup and sugars, and in the manufacture of adhesives and sizes for paper and textiles" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:CowMilk a wtm:Ingredient,
#         wtm:MilkFromCow,
#         owl:NamedIndividual ;
#     rdfs:label "cow milk" ;
#     dct:source "Wikipedia, \"Milk.\" [Online]. Available: https://en.wikipedia.org/wiki/Milk#Cow's_milk. [Accessed: Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "30"^^xsd:nonNegativeInteger ;
#     skos:definition "milk obtained from a cow" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Creamy a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "creamy" ;
#     dct:source "\"Creamy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/creamy. [Accessed: 18-Oct-2018]." ;
#     skos:definition "resembling cream (as in color, texture, or taste)" ;
#     skos:scopeNote "used as a texture" .
#
# ind:Crumbly a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "crumbly" ;
#     dct:source "\"Crumbly,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/crumbly. [Accessed: 18-Oct-2018]." ;
#     skos:definition "easily crumbled" ;
#     skos:scopeNote "used as a texture" .
#
# ind:DriedCranberry a obo:FOODON_03400756,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "dried cranberry" ;
#     dct:source "Wikipedia, \"Dried cranberry.\" [Online]. Available: https://en.wikipedia.org/wiki/Dried_cranberry. [Accessed: Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "30"^^xsd:nonNegativeInteger ;
#     skos:definition "an ingredient made by partially dehydrating fresh cranberries" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Fahrenheit a wtm:TemperatureMeasurement,
#         owl:NamedIndividual ;
#     rdfs:label "fahrenheit" ;
#     dct:source "\"Fahrenheit,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/Fahrenheit. [Accessed: 12-Oct-2018]." ;
#     skos:definition "relating or conforming to a thermometric scale on which under standard atmospheric pressure the boiling point of water is at 212 degrees above the zero of the scale, the freezing point is at 32 degrees above zero, and the zero point approximates the temperature produced by mixing equal quantities by weight of snow and common salt" ;
#     skos:editorialNote "A temperature scale that is used in recipes" ;
#     skos:scopeNote "value of temperature" .
#
# ind:Garlic a obo:FOODON_03400674,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "garlic" ;
#     dct:source "\"Garlic ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/garlic. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "30"^^xsd:nonNegativeInteger ;
#     skos:definition "widely cultivated for its pungent compound bulbs much used in cookery" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:GlutenFreeFlour a obo:FOODON_03400759,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "gluten free flour" ;
#     dct:source "Baking Bites, \"What is Gluten Free Flour?\"[Online]. Available: http://bakingbites.com/2013/01/what-is-gluten-free-flour/. [Accessed Nov. 1, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "95"^^xsd:nonNegativeInteger ;
#     wtm:substitutesFor ind:AllPurposeFlour ;
#     skos:definition "flours that are made of non-gluten containing products" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Gooey a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "gooey" ;
#     dct:source "\"Gooey,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/gooey. [Accessed: 18-Oct-2018]." ;
#     skos:definition "a viscid or sticky substance" ;
#     skos:scopeNote "used as a texture" .
#
# ind:Greasy a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "greasy" ;
#     dct:source "\"Greasy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/greasy. [Accessed: 18-Oct-2018]." ;
#     skos:definition "containing an unusual amount of grease" ;
#     skos:scopeNote "used as a texture" .
#
# ind:GreenOnion a obo:FOODON_03400674,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "green onion" ;
#     dct:source "Dictionary.com, \"green onion.\" [Online]. Available: https://www.dictionary.com/browse/green-onion. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "a young onion with a slender green stalk and a small bulb, used as a table vegetable, usually raw,especially in salads; scallion" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:GreenPepper a obo:FOODON_03400677,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "green pepper" ;
#     dct:source "Dictionary.com, \"green pepper.\" [Online]. Available: https://www.dictionary.com/browse/green-pepper. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "the mild-flavored, unripe fruit of the bell or sweet pepper, Capsicum annuum grossum, used as a greenvegetable" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Honey a obo:FOODON_03400666,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "honey" ;
#     dct:source "\"Honey,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/honey. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "60"^^xsd:nonNegativeInteger ;
#     skos:definition "a sweet viscid material elaborated out of the nectar of flowers in the honey sac of various bees" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Hour a wtm:TimeMeasurement,
#         owl:NamedIndividual ;
#     rdfs:label "hour" ;
#     dct:source "Dictionary.com, \"hour.\" [Online]. Available: https://www.dictionary.com/browse/hour. [Accessed Oct. 5, 2018]" ;
#     skos:altLabel "hours" ;
#     skos:definition "the measured or measurable period during which an action, process, or condition exists or continues" ;
#     skos:scopeNote "value of time" .
#
# ind:Kamut a obo:FOODON_03400683,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "kamut" ;
#     dct:source "Kamut, \"The grain,\" 2018. [Online]. Available: https://www.kamut.com/en/discover/the-grain. [Accessed Oct. 20, 2018]" ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "45"^^xsd:nonNegativeInteger ;
#     skos:definition "khorasan wheat (kamut) is an ancient grain" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:KamutFlour a obo:FOODON_03400759,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "kamut flour" ;
#     dct:source "foodrepublic.com, \"What Is Kamut?\" [Online]. Available: http://www.foodrepublic.com/2013/04/15/what-is-kamut/. [Accessed Nov.9, 2018]" ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "45"^^xsd:nonNegativeInteger ;
#     wtm:substitutesFor ind:AllPurposeFlour ;
#     skos:definition "flour made from an ancient grain also known as khorsan wheat" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Lamb a wtm:Ingredient,
#         wtm:MeatFromLamb,
#         owl:NamedIndividual ;
#     rdfs:label "lamb" ;
#     dct:source "\"Lamb,\" WIKIPEDIA [Online]. Available: https://en.wikipedia.org/wiki/Lamb [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the meat of sheep" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:LemonJuice a obo:FOODON_03400766,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "lemon juice" ;
#     dct:source "\"lemon juice,\" the free dictionary. [Online]. Available: https://www.thefreedictionary.com/lemon+juice. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "20"^^xsd:nonNegativeInteger ;
#     skos:definition "usually freshly squeezed juice of lemons" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Mayonnaise a obo:FOODON_03400776,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "mayonnaise" ;
#     dct:source "Dictionary.com, \"mayonnaise.\" [Online]. Available: https://www.dictionary.com/browse/mayonnaise. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "60"^^xsd:nonNegativeInteger ;
#     skos:definition "a thick dressing of egg yolks, vinegar or lemon juice, oil, and seasonings, used for salads, sandwiches,vegetable dishes, etc" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Minute a wtm:TimeMeasurement,
#         owl:NamedIndividual ;
#     rdfs:label "minute" ;
#     dct:source "Dictionary.com, \"minute.\" [Online]. Available: https://www.dictionary.com/browse/minute?s=t. [Accessed Oct. 5, 2018]" ;
#     skos:altLabel "minutes" ;
#     skos:definition "the sixtieth part (1/60) of an hour; sixty seconds" ;
#     skos:scopeNote "value of time" .
#
# ind:Moist a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "moist" ;
#     dct:source "\"Moist,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/moist. [Accessed: 18-Oct-2018]." ;
#     skos:definition "slightly or moderately wet" ;
#     skos:scopeNote "used as a texture" .
#
# ind:Mushy a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "mushy" ;
#     dct:source "\"Mushy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/mushy. [Accessed: 18-Oct-2018]." ;
#     skos:definition "having the consistency of mush" ;
#     skos:scopeNote "used as a texture" .
#
# ind:Nutty a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "nutty" ;
#     dct:source "\"Nutty,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/nutty. [Accessed: 12-Oct-2018]." ;
#     skos:definition "having a flavor like that of nuts" ;
#     skos:editorialNote "A property of flavor that will aid in the substitution decision making of the ontology" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:Oat a obo:FOODON_03400683,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "oat" ;
#     dct:source "Dictionary.com, \"oat.\" [Online]. Available: https://www.dictionary.com/browse/oat. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "40"^^xsd:nonNegativeInteger ;
#     skos:definition "a cereal grass, Avena sativa, cultivated for its edible seed" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:OliveOil a obo:FOODON_03400764,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "olive oil" ;
#     dct:source "\"Olive oil,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/olive%20oil. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a pale yellow to yellowish-green nondrying oil that is obtained from olives, is high in monounsaturated fat, and is used chiefly as a salad oil and in cooking" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Oregano a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "oregano" ;
#     dct:source "\"Oregano,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/oregano [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a bushy perennial mint (Origanum vulgare) with leaves that are used as a seasoning and a source of aromatic oil" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Paprika a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "paprika" ;
#     dct:source "\"Paprika ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/paprika. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "a usually mild red condiment consisting of the dried finely ground pods of various sweet peppers" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Parsley a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "parsley" ;
#     dct:source "\"Parsley ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/parsley. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a European biennial herb of the carrot family widely grown for its finely dissected curly or flat leaves which are used as an herb or garnish" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Peanut a obo:FOODON_03400686,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "peanut" ;
#     dct:source "Dictionary.com, \"peanut.\" [Online]. Available: https://www.dictionary.com/browse/peanut. [Accessed Oct. 5, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "the pod or the enclosed edible seed of the plant, Arachis hypogaea, of the legume family: the pod is forced underground in growing, where it ripens" ;
#     skos:editorialNote "This definition refers to the nuts of the plant as used as an ingredient in a recipe." ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Potato a obo:FOODON_03400681,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "potato" ;
#     dct:source "\"Potato,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/potato. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "70"^^xsd:nonNegativeInteger ;
#     skos:definition "a memeber of the nightshade family widely cultivated for its edible starchy tuber" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Rosemary a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "rosemary" ;
#     dct:source "\"Rosemary ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/rosemary. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a fragrant shrubby Mediterranean mint having grayish-green needlelike leaves used as a seasoning" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Salt a wtm:ChemicalFoodProduct,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "salt" ;
#     dct:source "\"Salt,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/salt. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a crystalline compound NaCl that consists of sodium chloride, is abundant in nature, and is used especially to season or preserve food or in industry" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Salty a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "salty" ;
#     dct:source "\"Salty,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/salty. [Accessed: 18-Oct-2018]." ;
#     skos:definition "of, seasoned with, or containing salt" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:SesameOil a obo:FOODON_03400764,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "sesame oil" ;
#     dct:source "Dictionary.com, \"sesame oil.\" [Online]. Available: https://www.dictionary.com/browse/sesame-oil. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a yellow oil expressed from the seeds of the sesame, used in cooking, as a vehicle for medicines, and in the manufacture of margarine, soap, and cosmetics" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Smoky a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "smoky" ;
#     dct:source "\"Smoky,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/smoky. [Accessed: 18-Oct-2018]." ;
#     skos:definition "suggestive of smoke especially in flavor or odor" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:SoySauce a obo:FOODON_03400663,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "soy sauce" ;
#     dct:source "Dictionary.com, \"soy sauce.\" [Online]. Available: https://www.dictionary.com/browse/soy-sauce. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "a salty, fermented sauce prepared from soybeans, used in East Asian cuisine" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Spicy a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "spicy" ;
#     dct:source "\"Spicy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/spicy. [Accessed: 18-Oct-2018]." ;
#     skos:definition "having the quality, flavor, or fragrance of spice" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:Sweet a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "sweet" ;
#     dct:source "\"Sweet,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/sweet. [Accessed: 18-Oct-2018]." ;
#     skos:definition "being or inducing the one of the four basic taste sensations that is typically induced by disaccharides and is mediated especially by receptors in taste buds at the front of the tongue" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:TapiocaFlour a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "tapioca flour" ;
#     dct:source "\"Tapioca,\" The Free Dictionary. [Online]. Available: https://www.thefreedictionary.com/Tapioca+flour. [Accessed Nov.9, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "85"^^xsd:nonNegativeInteger ;
#     skos:definition "a flour made from the tapioca plant" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Tarragon a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "tarragon" ;
#     dct:source "\"Tarragon ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tarragon. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a small widely cultivated perennial artemisia (Artemisia dracunculus) having aromatic narrow usually entire leaves, its leaves used as a seasoning" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Tart a wtm:Flavor,
#         owl:NamedIndividual ;
#     rdfs:label "tart" ;
#     dct:source "\"Tart,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tart. [Accessed: 18-Oct-2018]." ;
#     skos:definition "agreeably sharp or acid to the taste" ;
#     skos:scopeNote "used as a flavor" .
#
# ind:Thyme a obo:FOODON_03400688,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "thyme" ;
#     dct:source "\"Thyme,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/thyme. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "any of a genus (Thymus) of Eurasian mints with small pungent aromatic leaves" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Tomato a obo:FOODON_03400677,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "tomato" ;
#     dct:source "\"Tomato,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tomato. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "30"^^xsd:nonNegativeInteger ;
#     skos:definition "the usually large, rounded, edible, pulpy berry of an herb (genus Solanum) of the nightshade family native to South America that is typically red but may be yellow, orange, green, or purplish in color and is eaten raw or cooked as a vegetable" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:User15 a wtm:User,
#         owl:NamedIndividual ;
#     rdfs:label "user 15" ;
#     dct:source "Techopedia, \"User Identification (User ID),\" 2018. [Online]. Available: https://www.techopedia.com/definition/12552/user-identification-user-id. [Accessed Oct. 18, 2018]" ;
#     wtm:dislikes ind:Almond,
#         ind:Celery ;
#     wtm:forbids ind:Onion ;
#     wtm:isAllergicTo ind:Pecan ;
#     skos:definition "the user with ID 15" ;
#     skos:scopeNote "represents an individual user" .
#
# ind:VanillaExtract a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "vanilla extract" ;
#     dct:source "Wikipedia, \"Vanilla extract.\" [Online]. Available: https://en.wikipedia.org/wiki/Vanilla_extract. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a solution made by macerating and percolating vanilla pods in a solution of ethanol and water" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:VegetableOil a obo:FOODON_03400764,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "vegetable oil" ;
#     dct:source "\"Vegetable Oil ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/vegetable oil. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "an oil of plant origin" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Water a wtm:ChemicalFoodProduct,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "water" ;
#     dct:source "\"Water ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/water. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "0"^^xsd:nonNegativeInteger ;
#     skos:definition "the liquid that descends from the clouds as rain, forms streams, lakes, and seas, and is a major constituent of all living matter and that when pure is an odorless, tasteless, very slightly compressible liquid oxide of hydrogen H2O which appears bluish in thick layers, freezes at 0° C and boils at 100° C, has a maximum density at 4° C and a high specific heat, is feebly ionized to hydrogen and hydroxyl ions, and is a poor conductor of electricity and a good solvent" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:WhiteSugar a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "white sugar" ;
#     dct:source "\"Sugar,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/sugar. [Accessed: 1-Nov-2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "70"^^xsd:nonNegativeInteger ;
#     skos:definition "a sweet crystallizable material that consists wholly or essentially of sucrose, is colorless or white when pure tending to brown when less refined, is obtained commercially from sugarcane or sugar beet and less extensively from sorghum, maples, and palms, and is important as a source of dietary carbohydrate and as a sweetener and preservative of other foods" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:WhiteVinegar a obo:FOODON_03400662,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "white vinegar" ;
#     dct:source "Dictionary.com, \"vinegar.\" [Online]. Available: https://www.dictionary.com/browse/vinegar. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "5"^^xsd:nonNegativeInteger ;
#     skos:definition "a sour liquid consisting of dilute and impure acetic acid" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:WholeGrainMustard a obo:FOODON_03400663,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "whole grain mustard" ;
#     dct:source "TasteofHome, \"What Is Whole Grain Mustard?,\" 2018. [Online]. Available: https://www.tasteofhome.com/cooking-tips/ask-the-test-kitchen/what-is-whole-grain-mustard-. [Accessed Oct. 27 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "55"^^xsd:nonNegativeInteger ;
#     skos:definition "prepared mustard with visible mustard seeds" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:WholeWheatFlour a obo:FOODON_03400759,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "whole wheat flour" ;
#     dct:source "\"Whole Wheat Flour ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/whole wheat flour. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "40"^^xsd:nonNegativeInteger ;
#     wtm:substitutesFor ind:AllPurposeFlour ;
#     skos:definition "flour that is ground from the whole grain and contains all the constituents of the wheat kernels" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind: a owl:Ontology ;
#     rdfs:label "What to Make Individuals" ;
#     dct:abstract "The WhatToMake Individuals Ontology contains the invididual recipes and food items used in those recipes that are available in the system. These individuals are defined using classes and properties that are defined in the WhatToMake Base Ontology."^^xsd:string ;
#     dct:contributor "Forest Eckhardt",
#         "Kevin Blissett",
#         "Miao Qi",
#         "Yarden Ne'eman" ;
#     dct:description "The goal of this project is to create a system capable of recommending recipes to a user subject to the ingredients that user has on hand and the time they want to spend cooking. The system should also be able to recommend best-matched substitutions for ingredients where appropriate in order to meet the user’s taste preferences or food allergy related needs. The users are allowed to specify the meal types (e.g. lunch) and course types (e.g. entree) in the request. If the users request not to have recipes that contain high Glycemic Index (GI) ingredients, the system will avoid offering these high glycemic recipes in the recommendations." ;
#     dct:license "http://opensource.org/licenses/MIT"^^xsd:anyURI ;
#     dct:modified "2019-04-12"^^xsd:date ;
#     dct:publisher "WhatToMake" ;
#     dct:references "https://tw.rpi.edu/web/Courses/Ontologies/2018/Project2/maintenance" ;
#     owl:imports wtm:,
#         <http://www.omg.org/techprocess/ab/SpecificationMetadata/> ;
#     owl:priorVersion "https://tw.rpi.edu/Courses/Ontologies/2018/WhatToMake/WhatToMake_Individuals/" ;
#     owl:versionIRI ind: ;
#     skos:changeNote "Changes to this ontology since the previous version include: update of ontology IRI" ;
#     sm:copyright "Copyright (c) 2018 Kevin Blissett, Forest Eckhardt, Yarden Ne'eman, Miao Qi" .
#
# ind:Celery a obo:FOODON_03400682,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "celery" ;
#     dct:source "\"Celery ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/celery. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "a European herb the carrot family specifically one of a cultivated variety with leafstalks eaten raw or cooked" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Onion a obo:FOODON_03400674,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "onion" ;
#     dct:source "\"Onion ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/onion. [Accessed: 26-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     skos:definition "a widely cultivated Asian herb of the lily family with pungent edible bulbs" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:PumpkinSeed a obo:FOODON_03400686,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "pumpkin seed" ;
#     dct:source "\"pumpkin seed - Dictionary Definition,\" Vocabulary.com. [Online]. Available: https://www.vocabulary.com/dictionary/pumpkin seed. [Accessed: 12-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "10"^^xsd:nonNegativeInteger ;
#     wtm:substitutesFor ind:Walnut ;
#     skos:definition "the edible seed of a pumpkin" ;
#     skos:editorialNote "A potential substitution for members of the tree nut family" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:AllPurposeFlour a obo:FOODON_03400759,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "all purpose flour" ;
#     dct:source "\"Flour,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/flour. [Accessed: 13-Oct-2018]." ;
#     wtm:hasGluten true ;
#     wtm:hasGlycemicIndex "71"^^xsd:nonNegativeInteger ;
#     skos:definition "a product consisting of finely milled wheat" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Almond a obo:FOODON_03400685,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "almond" ;
#     dct:source "Dictionary.com, \"almond.\" [Online]. Available: https://www.dictionary.com/browse/almond. [Accessed Oct. 20, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     wtm:hasTexture ind:Crunchy ;
#     wtm:substitutesFor ind:Pecan,
#         ind:PumpkinSeed,
#         ind:Walnut ;
#     skos:definition "the nutlike kernel of the fruit of either of two trees, Prunus dulcis (sweet almond) or P. dulcis amara (bitter almond), which grow in warm temperate regions" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Crunchy a wtm:Texture,
#         owl:NamedIndividual ;
#     rdfs:label "crunchy" ;
#     dct:source "\"Crunchy,\" Dictionary.com. [Online]. Available: https://www.dictionary.com/browse/crunchy?s=t. [Accessed: 12-Oct-2018]." ;
#     skos:definition "crisp, brittle" ;
#     skos:editorialNote "This is a subclass of texture and is one of the textural components that could be considered for substitutions" ;
#     skos:scopeNote "used as a texture" .
#
# ind:Pecan a obo:FOODON_03400685,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "pecan" ;
#     dct:source "Dictionary.com, \"pecan.\" [Online]. Available: https://www.dictionary.com/browse/pecan. [Accessed Nov. 10, 2018]" ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     wtm:hasTexture ind:Crunchy ;
#     wtm:substitutesFor ind:Almond,
#         ind:Walnut ;
#     skos:definition "a tall hickory tree, Carya illinoinensis, of the southern U.S. and Mexico, cultivated for its oval, smooth-shelled, edible nuts" ;
#     skos:scopeNote "used as an ingredient" .
#
# ind:Walnut a obo:FOODON_03400685,
#         wtm:Ingredient,
#         owl:NamedIndividual ;
#     rdfs:label "walnut" ;
#     dct:source "\"Walnut,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/walnut. [Accessed: 12-Oct-2018]." ;
#     wtm:hasGluten false ;
#     wtm:hasGlycemicIndex "15"^^xsd:nonNegativeInteger ;
#     wtm:hasTexture ind:Crunchy ;
#     wtm:substitutesFor ind:Almond,
#         ind:Pecan,
#         ind:PumpkinSeed ;
#     skos:definition "the furrowed nut of any of a genus (Juglans of the family Juglandaceae, the walnut family) of deciduous trees" ;
#     skos:editorialNote "Member of the tree nut family which is a common allergen" ;
#     skos:scopeNote "used as an ingredient" .

# %%
serialize_graph("./data/ingredients.rdf", 'nt')
# Out:
# <http://purl.org/heals/ingredient/CanolaOil> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400764> .
# <http://purl.org/heals/ingredient/VanillaExtract> <http://purl.org/heals/food/hasGlycemicIndex> "5"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Smoky> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Flavor> .
# <http://purl.org/heals/ingredient/Paprika> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Tart> <http://www.w3.org/2000/01/rdf-schema#label> "tart" .
# <http://purl.org/heals/ingredient/Tomato> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/AlmondMeal> <http://purl.org/dc/terms/source> "Wikipedia, \"Almond meal.\" [Online]. Available:https://en.wikipedia.org/wiki/Almond_meal. [Accessed: Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/ChickenEgg> <http://www.w3.org/2004/02/skos/core#editorialNote> "Only used to refer to the egg of a chicken. Other types of eggs will appear under separate labels in the ontology." .
# <http://purl.org/heals/ingredient/DriedCranberry> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Carrot> <http://www.w3.org/2000/01/rdf-schema#label> "carrot" .
# <http://purl.org/heals/ingredient/AlmondMeal> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400662> .
# <http://purl.org/heals/ingredient/Blueberry> <http://www.w3.org/2004/02/skos/core#definition> "the edible, usually bluish berry of various shrubs belonging to the genus Vaccinium, of the heath family" .
# <http://purl.org/heals/ingredient/CaneSugar> <http://purl.org/dc/terms/source> "Dictionary.com, \"cane sugar.\" [Online]. Available: https://www.dictionary.com/browse/cane-sugar. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/ChickenEgg> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Paprika> <http://www.w3.org/2004/02/skos/core#definition> "a usually mild red condiment consisting of the dried finely ground pods of various sweet peppers" .
# <http://purl.org/heals/ingredient/Smoky> <http://www.w3.org/2004/02/skos/core#definition> "suggestive of smoke especially in flavor or odor" .
# <http://purl.org/heals/ingredient/Sweet> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Flavor> .
# <http://purl.org/heals/ingredient/Oat> <http://purl.org/dc/terms/source> "Dictionary.com, \"oat.\" [Online]. Available: https://www.dictionary.com/browse/oat. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/CoconutMilk> <http://www.w3.org/2000/01/rdf-schema#label> "coconut milk" .
# <http://purl.org/heals/ingredient/GreenOnion> <http://www.w3.org/2000/01/rdf-schema#label> "green onion" .
# <http://purl.org/heals/ingredient/Smoky> <http://www.w3.org/2000/01/rdf-schema#label> "smoky" .
# <http://purl.org/heals/ingredient/Paprika> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Almond> <http://purl.org/heals/food/hasTexture> <http://purl.org/heals/ingredient/Crunchy> .
# <http://purl.org/heals/ingredient/Tarragon> <http://purl.org/dc/terms/source> "\"Tarragon ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tarragon. [Accessed: 26-Oct-2018]." .
# <http://purl.org/heals/ingredient/Pecan> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Water> <http://www.w3.org/2000/01/rdf-schema#label> "water" .
# <http://purl.org/heals/ingredient/Banana> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400673> .
# <http://purl.org/heals/ingredient/Crumbly> <http://purl.org/dc/terms/source> "\"Crumbly,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/crumbly. [Accessed: 18-Oct-2018]." .
# <http://purl.org/heals/ingredient/ChickenEgg> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/WhiteVinegar> <http://www.w3.org/2004/02/skos/core#definition> "a sour liquid consisting of dilute and impure acetic acid" .
# <http://purl.org/heals/ingredient/BlackPeppercorn> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Blueberry> <http://www.w3.org/2000/01/rdf-schema#label> "blueberry" .
# <http://purl.org/heals/ingredient/CaneSugar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400662> .
# <http://purl.org/heals/ingredient/> <https://www.omg.org/techprocess/ab/SpecificationMetadata/copyright> "Copyright (c) 2018 Kevin Blissett, Forest Eckhardt, Yarden Ne'eman, Miao Qi" .
# <http://purl.org/heals/ingredient/Walnut> <http://www.w3.org/2004/02/skos/core#editorialNote> "Member of the tree nut family which is a common allergen" .
# <http://purl.org/heals/ingredient/> <http://purl.org/dc/terms/contributor> "Yarden Ne'eman" .
# <http://purl.org/heals/ingredient/BrownSugar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400662> .
# <http://purl.org/heals/ingredient/Salty> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a flavor" .
# <http://purl.org/heals/ingredient/BakingSoda> <http://purl.org/dc/terms/source> "\"Baking soda,\" the free dictionary. [Online]. Available: https://www.thefreedictionary.com/baking+soda [Accessed: 26-Oct-2018]." .
# <http://purl.org/heals/ingredient/WholeWheatFlour> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/BalsamicVinegar> <http://www.w3.org/2004/02/skos/core#definition> "an aged Italian vinegar made from the must of white grapes" .
# <http://purl.org/heals/ingredient/GreenPepper> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Spicy> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Thyme> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Oregano> <http://purl.org/dc/terms/source> "\"Oregano,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/oregano [Accessed: 1-Nov-2018]" .
# <http://purl.org/heals/ingredient/User15> <http://purl.org/heals/food/forbids> <http://purl.org/heals/ingredient/Onion> .
# <http://purl.org/heals/ingredient/BakersYeast> <http://purl.org/heals/food/hasGlycemicIndex> "35"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/WhiteVinegar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Salt> <http://www.w3.org/2000/01/rdf-schema#label> "salt" .
# <http://purl.org/heals/ingredient/KamutFlour> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Mushy> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/PumpkinSeed> <http://purl.org/heals/food/substitutesFor> <http://purl.org/heals/ingredient/Walnut> .
# <http://purl.org/heals/ingredient/VegetableOil> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/CornSyrup> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/WholeWheatFlour> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400759> .
# <http://purl.org/heals/ingredient/CaneSugar> <http://www.w3.org/2004/02/skos/core#definition> "sugar obtained from sugar cane, identical with that obtained from the sugar beet" .
# <http://purl.org/heals/ingredient/BalsamicVinegar> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Pecan> <http://purl.org/dc/terms/source> "Dictionary.com, \"pecan.\" [Online]. Available: https://www.dictionary.com/browse/pecan. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/Mayonnaise> <http://purl.org/heals/food/hasGluten> "true"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/WhiteVinegar> <http://purl.org/dc/terms/source> "Dictionary.com, \"vinegar.\" [Online]. Available: https://www.dictionary.com/browse/vinegar. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/Bacon> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400667> .
# <http://purl.org/heals/ingredient/Nutty> <http://www.w3.org/2004/02/skos/core#editorialNote> "A property of flavor that will aid in the substitution decision making of the ontology" .
# <http://purl.org/heals/ingredient/SoySauce> <http://www.w3.org/2004/02/skos/core#definition> "a salty, fermented sauce prepared from soybeans, used in East Asian cuisine" .
# <http://purl.org/heals/ingredient/Greasy> <http://www.w3.org/2000/01/rdf-schema#label> "greasy" .
# <http://purl.org/heals/ingredient/Onion> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Pecan> <http://purl.org/heals/food/substitutesFor> <http://purl.org/heals/ingredient/Walnut> .
# <http://purl.org/heals/ingredient/Potato> <http://purl.org/heals/food/hasGlycemicIndex> "70"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Cabbage> <http://www.w3.org/2004/02/skos/core#definition> "any of several brassicas of European origin especially a leafy garden plant with a short stem and a dense globular head of usually green leaves that is used as a vegetable" .
# <http://purl.org/heals/ingredient/Garlic> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Potato> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/BakingPowder> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/ChemicalFoodProduct> .
# <http://purl.org/heals/ingredient/Kamut> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/> <http://purl.org/dc/terms/abstract> "The WhatToMake Individuals Ontology contains the invididual recipes and food items used in those recipes that are available in the system. These individuals are defined using classes and properties that are defined in the WhatToMake Base Ontology."^^<http://www.w3.org/2001/XMLSchema#string> .
# <http://purl.org/heals/ingredient/Fahrenheit> <http://purl.org/dc/terms/source> "\"Fahrenheit,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/Fahrenheit. [Accessed: 12-Oct-2018]." .
# <http://purl.org/heals/ingredient/Tarragon> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400688> .
# <http://purl.org/heals/ingredient/Banana> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Salty> <http://www.w3.org/2004/02/skos/core#definition> "of, seasoned with, or containing salt" .
# <http://purl.org/heals/ingredient/SesameOil> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Cornstarch> <http://www.w3.org/2004/02/skos/core#definition> "starch made from corn and used in foods as a thickening agent, in making corn syrup and sugars, and in the manufacture of adhesives and sizes for paper and textiles" .
# <http://purl.org/heals/ingredient/Kamut> <http://www.w3.org/2004/02/skos/core#definition> "khorasan wheat (kamut) is an ancient grain" .
# <http://purl.org/heals/ingredient/> <http://purl.org/dc/terms/publisher> "WhatToMake" .
# <http://purl.org/heals/ingredient/Greasy> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a texture" .
# <http://purl.org/heals/ingredient/BakersYeast> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Lamb> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Spicy> <http://www.w3.org/2004/02/skos/core#definition> "having the quality, flavor, or fragrance of spice" .
# <http://purl.org/heals/ingredient/Almond> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Peanut> <http://purl.org/heals/food/hasGlycemicIndex> "15"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Banana> <http://purl.org/dc/terms/source> "\"Banana ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/banana. [Accessed: 26-Oct-2018]." .
# <http://purl.org/heals/ingredient/Kamut> <http://www.w3.org/2000/01/rdf-schema#label> "kamut" .
# <http://purl.org/heals/ingredient/Cabbage> <http://purl.org/heals/food/hasGlycemicIndex> "15"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Mayonnaise> <http://purl.org/heals/food/hasGlycemicIndex> "60"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/SoySauce> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/ChickenEgg> <http://www.w3.org/2004/02/skos/core#definition> "the roundish reproductive body produced by a female chicken" .
# <http://purl.org/heals/ingredient/WholeGrainMustard> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/> <http://purl.org/dc/terms/contributor> "Kevin Blissett" .
# <http://purl.org/heals/ingredient/AlmondMeal> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Basil> <http://www.w3.org/2004/02/skos/core#definition> "the dried or fresh leaves of a basil used especially as a seasoning" .
# <http://purl.org/heals/ingredient/OliveOil> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Cornstarch> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Bacon> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/VegetableOil> <http://purl.org/dc/terms/source> "\"Vegetable Oil ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/vegetable oil. [Accessed: 26-Oct-2018]." .
# <http://purl.org/heals/ingredient/ChickenEgg> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400744> .
# <http://purl.org/heals/ingredient/Butter> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Moist> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a texture" .
# <http://purl.org/heals/ingredient/VanillaExtract> <http://purl.org/dc/terms/source> "Wikipedia, \"Vanilla extract.\" [Online]. Available: https://en.wikipedia.org/wiki/Vanilla_extract. [Accessed: 1-Nov-2018]" .
# <http://purl.org/heals/ingredient/Blueberry> <http://purl.org/dc/terms/source> "Dictionary.com, \"blueberry.\" [Online]. Available: https://www.dictionary.com/browse/blueberry. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/Tarragon> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Beef> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/GlutenFreeFlour> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/CocoaPowder> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400663> .
# <http://purl.org/heals/ingredient/Mushy> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Texture> .
# <http://purl.org/heals/ingredient/Cheese> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/BakingPowder> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Cheese> <http://purl.org/dc/terms/source> "Dictionary.com, \"cheese.\" [Online]. Available: https://www.dictionary.com/browse/cheese. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/Greasy> <http://purl.org/dc/terms/source> "\"Greasy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/greasy. [Accessed: 18-Oct-2018]." .
# <http://purl.org/heals/ingredient/Walnut> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Creamy> <http://purl.org/dc/terms/source> "\"Creamy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/creamy. [Accessed: 18-Oct-2018]." .
# <http://purl.org/heals/ingredient/Oregano> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400688> .
# <http://purl.org/heals/ingredient/Rosemary> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/CaneSugar> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/AlmondMeal> <http://www.w3.org/2004/02/skos/core#definition> "an ingredient made from ground up almonds" .
# <http://purl.org/heals/ingredient/Cilantro> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Sweet> <http://www.w3.org/2000/01/rdf-schema#label> "sweet" .
# <http://purl.org/heals/ingredient/BrownSugar> <http://www.w3.org/2004/02/skos/core#definition> "soft sugar whose crystals are covered by a film of refined dark syrup" .
# <http://purl.org/heals/ingredient/Almond> <http://purl.org/heals/food/substitutesFor> <http://purl.org/heals/ingredient/Walnut> .
# <http://purl.org/heals/ingredient/Thyme> <http://purl.org/dc/terms/source> "\"Thyme,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/thyme. [Accessed: 1-Nov-2018]" .
# <http://purl.org/heals/ingredient/Nutty> <http://www.w3.org/2004/02/skos/core#definition> "having a flavor like that of nuts" .
# <http://purl.org/heals/ingredient/CoconutMilk> <http://purl.org/heals/food/hasGlycemicIndex> "40"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/BakingPowder> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Water> <http://www.w3.org/2004/02/skos/core#definition> "the liquid that descends from the clouds as rain, forms streams, lakes, and seas, and is a major constituent of all living matter and that when pure is an odorless, tasteless, very slightly compressible liquid oxide of hydrogen H2O which appears bluish in thick layers, freezes at 0° C and boils at 100° C, has a maximum density at 4° C and a high specific heat, is feebly ionized to hydrogen and hydroxyl ions, and is a poor conductor of electricity and a good solvent" .
# <http://purl.org/heals/ingredient/Minute> <http://www.w3.org/2004/02/skos/core#scopeNote> "value of time" .
# <http://purl.org/heals/ingredient/Fahrenheit> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/BakingSoda> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/CocoaPowder> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Paprika> <http://www.w3.org/2000/01/rdf-schema#label> "paprika" .
# <http://purl.org/heals/ingredient/BlackPepper> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Banana> <http://www.w3.org/2000/01/rdf-schema#label> "banana" .
# <http://purl.org/heals/ingredient/SoySauce> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Parsley> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/BeefBouillon> <http://www.w3.org/2000/01/rdf-schema#label> "beef bouillon" .
# <http://purl.org/heals/ingredient/Creamy> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Salty> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Flavor> .
# <http://purl.org/heals/ingredient/User15> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/User> .
# <http://purl.org/heals/ingredient/Carrot> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400681> .
# <http://purl.org/heals/ingredient/OliveOil> <http://www.w3.org/2000/01/rdf-schema#label> "olive oil" .
# <http://purl.org/heals/ingredient/Butter> <http://www.w3.org/2000/01/rdf-schema#label> "butter" .
# <http://purl.org/heals/ingredient/ChickenBroth> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Butter> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400774> .
# <http://purl.org/heals/ingredient/AllPurposeFlour> <http://www.w3.org/2004/02/skos/core#definition> "a product consisting of finely milled wheat" .
# <http://purl.org/heals/ingredient/ChickenBroth> <http://purl.org/dc/terms/source> "vocabulary.com, \"chicken broth.\" [Online]. Available: https://www.vocabulary.com/dictionary/chicken%20broth. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/SesameOil> <http://www.w3.org/2004/02/skos/core#definition> "a yellow oil expressed from the seeds of the sesame, used in cooking, as a vehicle for medicines, and in the manufacture of margarine, soap, and cosmetics" .
# <http://purl.org/heals/ingredient/Cilantro> <http://purl.org/dc/terms/source> "Dictionary.com, \"cilantro.\" [Online]. Available: https://www.dictionary.com/browse/cilantro. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/Oregano> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/DriedCranberry> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400756> .
# <http://purl.org/heals/ingredient/Rosemary> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Tart> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a flavor" .
# <http://purl.org/heals/ingredient/Basil> <http://purl.org/heals/food/hasGlycemicIndex> "5"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Beef> <http://www.w3.org/2004/02/skos/core#definition> "the flesh of an adult domestic bovine used as food" .
# <http://purl.org/heals/ingredient/ChayoteSquash> <http://www.w3.org/2000/01/rdf-schema#label> "chayote squash" .
# <http://purl.org/heals/ingredient/SoySauce> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/CowMilk> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Peanut> <http://www.w3.org/2000/01/rdf-schema#label> "peanut" .
# <http://purl.org/heals/ingredient/Hour> <http://purl.org/dc/terms/source> "Dictionary.com, \"hour.\" [Online]. Available: https://www.dictionary.com/browse/hour. [Accessed Oct. 5, 2018]" .
# <http://purl.org/heals/ingredient/Peanut> <http://www.w3.org/2004/02/skos/core#definition> "the pod or the enclosed edible seed of the plant, Arachis hypogaea, of the legume family: the pod is forced underground in growing, where it ripens" .
# <http://purl.org/heals/ingredient/Minute> <http://www.w3.org/2000/01/rdf-schema#label> "minute" .
# <http://purl.org/heals/ingredient/VanillaExtract> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/ChickenEgg> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Gooey> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a texture" .
# <http://purl.org/heals/ingredient/BlackPeppercorn> <http://www.w3.org/2004/02/skos/core#definition> "a dried berry of the black pepper" .
# <http://purl.org/heals/ingredient/AppleCiderVinegar> <http://purl.org/heals/food/hasGlycemicIndex> "5"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Walnut> <http://purl.org/heals/food/substitutesFor> <http://purl.org/heals/ingredient/Almond> .
# <http://purl.org/heals/ingredient/ChickenEgg> <http://www.w3.org/2000/01/rdf-schema#label> "chicken egg" .
# <http://purl.org/heals/ingredient/WhiteVinegar> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Tomato> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400677> .
# <http://purl.org/heals/ingredient/Tart> <http://purl.org/dc/terms/source> "\"Tart,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tart. [Accessed: 18-Oct-2018]." .
# <http://purl.org/heals/ingredient/WholeWheatFlour> <http://www.w3.org/2000/01/rdf-schema#label> "whole wheat flour" .
# <http://purl.org/heals/ingredient/WholeWheatFlour> <http://purl.org/heals/food/hasGlycemicIndex> "40"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Chicken> <http://www.w3.org/2000/01/rdf-schema#label> "chicken" .
# <http://purl.org/heals/ingredient/Tarragon> <http://www.w3.org/2004/02/skos/core#definition> "a small widely cultivated perennial artemisia (Artemisia dracunculus) having aromatic narrow usually entire leaves, its leaves used as a seasoning" .
# <http://purl.org/heals/ingredient/Celsius> <http://www.w3.org/2004/02/skos/core#editorialNote> "A temperature scale that is used in recipes" .
# <http://purl.org/heals/ingredient/Blueberry> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/ChuckRoast> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Nutty> <http://purl.org/dc/terms/source> "\"Nutty,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/nutty. [Accessed: 12-Oct-2018]." .
# <http://purl.org/heals/ingredient/Chicken> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/CocoaPowder> <http://www.w3.org/2000/01/rdf-schema#label> "cocoa powder" .
# <http://purl.org/heals/ingredient/CornedBeef> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/BrownSugar> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/WhiteVinegar> <http://www.w3.org/2000/01/rdf-schema#label> "white vinegar" .
# <http://purl.org/heals/ingredient/LemonJuice> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/KamutFlour> <http://www.w3.org/2000/01/rdf-schema#label> "kamut flour" .
# <http://purl.org/heals/ingredient/CowMilk> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/User15> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/User15> <http://purl.org/heals/food/dislikes> <http://purl.org/heals/ingredient/Almond> .
# <http://purl.org/heals/ingredient/Onion> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/OliveOil> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Fahrenheit> <http://www.w3.org/2004/02/skos/core#definition> "relating or conforming to a thermometric scale on which under standard atmospheric pressure the boiling point of water is at 212 degrees above the zero of the scale, the freezing point is at 32 degrees above zero, and the zero point approximates the temperature produced by mixing equal quantities by weight of snow and common salt" .
# <http://purl.org/heals/ingredient/VanillaExtract> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Beef> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Cornstarch> <http://purl.org/heals/food/hasGlycemicIndex> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Garlic> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Potato> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Hour> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/> <http://www.w3.org/2004/02/skos/core#changeNote> "Changes to this ontology since the previous version include: update of ontology IRI" .
# <http://purl.org/heals/ingredient/Smoky> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/AllPurposeFlour> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/KamutFlour> <http://purl.org/heals/food/hasGlycemicIndex> "45"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/PumpkinSeed> <http://purl.org/heals/food/hasGlycemicIndex> "10"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Celsius> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/TemperatureMeasurement> .
# <http://purl.org/heals/ingredient/Potato> <http://www.w3.org/2004/02/skos/core#definition> "a memeber of the nightshade family widely cultivated for its edible starchy tuber" .
# <http://purl.org/heals/ingredient/Crunchy> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a texture" .
# <http://purl.org/heals/ingredient/Nutty> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a flavor" .
# <http://purl.org/heals/ingredient/Blueberry> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/BakingPowder> <http://www.w3.org/2004/02/skos/core#definition> "a powder used as a leavening agent in making baked goods (such as quick breads) that typically consists of sodium bicarbonate, an acidic substance (such as cream of tartar), and starch or flour" .
# <http://purl.org/heals/ingredient/Almond> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400685> .
# <http://purl.org/heals/ingredient/Creamy> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Texture> .
# <http://purl.org/heals/ingredient/GreenPepper> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400677> .
# <http://purl.org/heals/ingredient/Potato> <http://purl.org/dc/terms/source> "\"Potato,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/potato. [Accessed: 13-Oct-2018]." .
# <http://purl.org/heals/ingredient/Tomato> <http://purl.org/dc/terms/source> "\"Tomato,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tomato. [Accessed: 1-Nov-2018]" .
# <http://purl.org/heals/ingredient/BakersYeast> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/BakersYeast> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Yeast> .
# <http://purl.org/heals/ingredient/Clove> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400674> .
# <http://purl.org/heals/ingredient/Crunchy> <http://www.w3.org/2004/02/skos/core#editorialNote> "This is a subclass of texture and is one of the textural components that could be considered for substitutions" .
# <http://purl.org/heals/ingredient/Basil> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400688> .
# <http://purl.org/heals/ingredient/SoySauce> <http://www.w3.org/2000/01/rdf-schema#label> "soy sauce" .
# <http://purl.org/heals/ingredient/> <http://www.w3.org/2002/07/owl#imports> <http://www.omg.org/techprocess/ab/SpecificationMetadata/> .
# <http://purl.org/heals/ingredient/ChuckRoast> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/TapiocaFlour> <http://purl.org/heals/food/hasGlycemicIndex> "85"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/WhiteSugar> <http://www.w3.org/2000/01/rdf-schema#label> "white sugar" .
# <http://purl.org/heals/ingredient/Celery> <http://purl.org/dc/terms/source> "\"Celery ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/celery. [Accessed: 26-Oct-2018]." .
# <http://purl.org/heals/ingredient/WholeWheatFlour> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/GreenOnion> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Minute> <http://www.w3.org/2004/02/skos/core#definition> "the sixtieth part (1/60) of an hour; sixty seconds" .
# <http://purl.org/heals/ingredient/CoconutMilk> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Thyme> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/WholeGrainMustard> <http://www.w3.org/2000/01/rdf-schema#label> "whole grain mustard" .
# <http://purl.org/heals/ingredient/Paprika> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/AlmondMeal> <http://www.w3.org/2000/01/rdf-schema#label> "almond meal" .
# <http://purl.org/heals/ingredient/CanolaOil> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/CanolaOil> <http://purl.org/dc/terms/source> "Wikipedia, \"Canola oil.\" [Online]. Available: https://en.wikipedia.org/wiki/Canola_oil. [Accessed: Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/OliveOil> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/BakersYeast> <http://purl.org/dc/terms/source> "Wikipedia, \"Baker's yeast.\" [Online]. Available: https://en.wikipedia.org/wiki/Baker%27s_yeast. [Accessed: Nov. 22, 2018]" .
# <http://purl.org/heals/ingredient/Cabbage> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Gooey> <http://purl.org/dc/terms/source> "\"Gooey,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/gooey. [Accessed: 18-Oct-2018]." .
# <http://purl.org/heals/ingredient/Kamut> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Kamut> <http://purl.org/dc/terms/source> "Kamut, \"The grain,\" 2018. [Online]. Available: https://www.kamut.com/en/discover/the-grain. [Accessed Oct. 20, 2018]" .
# <http://purl.org/heals/ingredient/Peanut> <http://purl.org/dc/terms/source> "Dictionary.com, \"peanut.\" [Online]. Available: https://www.dictionary.com/browse/peanut. [Accessed Oct. 5, 2018]" .
# <http://purl.org/heals/ingredient/Butter> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Tarragon> <http://www.w3.org/2000/01/rdf-schema#label> "tarragon" .
# <http://purl.org/heals/ingredient/Banana> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/BrownSugar> <http://www.w3.org/2000/01/rdf-schema#label> "brown sugar" .
# <http://purl.org/heals/ingredient/Salt> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/BakersYeast> <http://www.w3.org/2004/02/skos/core#definition> "the strains of yeast commonly used as a leavening agent in baking bread and bakery products, where it converts the fermentable sugars present in the dough into carbon dioxide and ethanol" .
# <http://purl.org/heals/ingredient/GlutenFreeFlour> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/CowMilk> <http://www.w3.org/2000/01/rdf-schema#label> "cow milk" .
# <http://purl.org/heals/ingredient/Peanut> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/BlackPepper> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400689> .
# <http://purl.org/heals/ingredient/ChayoteSquash> <http://purl.org/heals/food/hasGlycemicIndex> "50"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Beef> <http://purl.org/dc/terms/source> "\"Beef,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/beef. [Accessed: 13-Oct-2018]." .
# <http://purl.org/heals/ingredient/PumpkinSeed> <http://www.w3.org/2000/01/rdf-schema#label> "pumpkin seed" .
# <http://purl.org/heals/ingredient/TapiocaFlour> <http://www.w3.org/2004/02/skos/core#definition> "a flour made from the tapioca plant" .
# <http://purl.org/heals/ingredient/VegetableOil> <http://www.w3.org/2000/01/rdf-schema#label> "vegetable oil" .
# <http://purl.org/heals/ingredient/Clove> <http://purl.org/heals/food/hasGlycemicIndex> "5"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Walnut> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Basil> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Tart> <http://www.w3.org/2004/02/skos/core#definition> "agreeably sharp or acid to the taste" .
# <http://purl.org/heals/ingredient/Bitter> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a flavor" .
# <http://purl.org/heals/ingredient/AllPurposeFlour> <http://purl.org/dc/terms/source> "\"Flour,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/flour. [Accessed: 13-Oct-2018]." .
# <http://purl.org/heals/ingredient/Oat> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/VanillaExtract> <http://www.w3.org/2004/02/skos/core#definition> "a solution made by macerating and percolating vanilla pods in a solution of ethanol and water" .
# <http://purl.org/heals/ingredient/SoySauce> <http://purl.org/dc/terms/source> "Dictionary.com, \"soy sauce.\" [Online]. Available: https://www.dictionary.com/browse/soy-sauce. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/Pecan> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400685> .
# <http://purl.org/heals/ingredient/Almond> <http://purl.org/heals/food/substitutesFor> <http://purl.org/heals/ingredient/Pecan> .
# <http://purl.org/heals/ingredient/BlackPeppercorn> <http://www.w3.org/2000/01/rdf-schema#label> "black peppercorn" .
# <http://purl.org/heals/ingredient/Tart> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Flavor> .
# <http://purl.org/heals/ingredient/User15> <http://purl.org/heals/food/dislikes> <http://purl.org/heals/ingredient/Celery> .
# <http://purl.org/heals/ingredient/Parsley> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/ChuckRoast> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/MeatFromCow> .
# <http://purl.org/heals/ingredient/ChuckRoast> <http://www.w3.org/2000/01/rdf-schema#label> "chuck roast" .
# <http://purl.org/heals/ingredient/Cheese> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400775> .
# <http://purl.org/heals/ingredient/Peanut> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/GreenOnion> <http://www.w3.org/2004/02/skos/core#definition> "a young onion with a slender green stalk and a small bulb, used as a table vegetable, usually raw,especially in salads; scallion" .
# <http://purl.org/heals/ingredient/PumpkinSeed> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400686> .
# <http://purl.org/heals/ingredient/Greasy> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/WholeGrainMustard> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Crunchy> <http://www.w3.org/2000/01/rdf-schema#label> "crunchy" .
# <http://purl.org/heals/ingredient/AlmondMeal> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/BlackPeppercorn> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/WhiteSugar> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Cabbage> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400675> .
# <http://purl.org/heals/ingredient/Cornstarch> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Beef> <http://www.w3.org/2000/01/rdf-schema#label> "beef" .
# <http://purl.org/heals/ingredient/SesameOil> <http://purl.org/dc/terms/source> "Dictionary.com, \"sesame oil.\" [Online]. Available: https://www.dictionary.com/browse/sesame-oil. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/VegetableOil> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Thyme> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/TapiocaFlour> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/GreenPepper> <http://purl.org/heals/food/hasGlycemicIndex> "15"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Clove> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Almond> <http://www.w3.org/2004/02/skos/core#definition> "the nutlike kernel of the fruit of either of two trees, Prunus dulcis (sweet almond) or P. dulcis amara (bitter almond), which grow in warm temperate regions" .
# <http://purl.org/heals/ingredient/PumpkinSeed> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/AllPurposeFlour> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/WhiteVinegar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Tarragon> <http://purl.org/heals/food/hasGlycemicIndex> "5"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Blueberry> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400671> .
# <http://purl.org/heals/ingredient/Cheese> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/GlutenFreeFlour> <http://purl.org/heals/food/hasGlycemicIndex> "95"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#Ontology> .
# <http://purl.org/heals/ingredient/CaneSugar> <http://purl.org/heals/food/hasGlycemicIndex> "70"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Moist> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/BakingSoda> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/CaneSugar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/KamutFlour> <http://purl.org/heals/food/substitutesFor> <http://purl.org/heals/ingredient/AllPurposeFlour> .
# <http://purl.org/heals/ingredient/Cilantro> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Rosemary> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Sweet> <http://purl.org/dc/terms/source> "\"Sweet,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/sweet. [Accessed: 18-Oct-2018]." .
# <http://purl.org/heals/ingredient/KamutFlour> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Salt> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/BrownSugar> <http://purl.org/heals/food/hasGlycemicIndex> "70"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/BeefBouillon> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Bacon> <http://purl.org/dc/terms/source> "Dictionary.com, \"bacon.\" [Online]. Available: https://www.dictionary.com/browse/bacon. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/BrownSugar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Spicy> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a flavor" .
# ...
# <http://purl.org/heals/ingredient/GreenOnion> <http://purl.org/dc/terms/source> "Dictionary.com, \"green onion.\" [Online]. Available: https://www.dictionary.com/browse/green-onion. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/Smoky> <http://purl.org/dc/terms/source> "\"Smoky,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/smoky. [Accessed: 18-Oct-2018]." .
# <http://purl.org/heals/ingredient/WhiteSugar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400662> .
# <http://purl.org/heals/ingredient/Water> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/ChemicalFoodProduct> .
# <http://purl.org/heals/ingredient/Basil> <http://www.w3.org/2000/01/rdf-schema#label> "basil" .
# <http://purl.org/heals/ingredient/WholeGrainMustard> <http://purl.org/heals/food/hasGlycemicIndex> "55"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/CocoaPowder> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Tart> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/BalsamicVinegar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Celery> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Celery> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400682> .
# <http://purl.org/heals/ingredient/Fahrenheit> <http://www.w3.org/2004/02/skos/core#scopeNote> "value of temperature" .
# <http://purl.org/heals/ingredient/Celsius> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/KamutFlour> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400759> .
# <http://purl.org/heals/ingredient/Garlic> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Pecan> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/CowMilk> <http://purl.org/dc/terms/source> "Wikipedia, \"Milk.\" [Online]. Available: https://en.wikipedia.org/wiki/Milk#Cow's_milk. [Accessed: Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/Potato> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/TapiocaFlour> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/WholeWheatFlour> <http://purl.org/dc/terms/source> "\"Whole Wheat Flour ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/whole wheat flour. [Accessed: 26-Oct-2018]." .
# <http://purl.org/heals/ingredient/PumpkinSeed> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Sweet> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a flavor" .
# <http://purl.org/heals/ingredient/ChickenBroth> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/CornedBeef> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Salt> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/CoconutMilk> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400662> .
# <http://purl.org/heals/ingredient/DriedCranberry> <http://purl.org/dc/terms/source> "Wikipedia, \"Dried cranberry.\" [Online]. Available: https://en.wikipedia.org/wiki/Dried_cranberry. [Accessed: Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/BakingPowder> <http://purl.org/dc/terms/source> "\"Baking powder,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/baking%20powder. [Accessed: 1-Nov-2018]" .
# <http://purl.org/heals/ingredient/Oregano> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/SesameOil> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Hour> <http://www.w3.org/2004/02/skos/core#altLabel> "hours" .
# <http://purl.org/heals/ingredient/Lamb> <http://www.w3.org/2000/01/rdf-schema#label> "lamb" .
# <http://purl.org/heals/ingredient/BakersYeast> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/GreenPepper> <http://purl.org/dc/terms/source> "Dictionary.com, \"green pepper.\" [Online]. Available: https://www.dictionary.com/browse/green-pepper. [Accessed Nov. 10, 2018]" .
# <http://purl.org/heals/ingredient/BeefBouillon> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/BakingSoda> <http://www.w3.org/2004/02/skos/core#definition> "a white crystalline compound, NaHCO3, chemically known as sodium bicarbonate, that is used especially in beverages and as a leavening agent to make baked goods" .
# <http://purl.org/heals/ingredient/TapiocaFlour> <http://www.w3.org/2000/01/rdf-schema#label> "tapioca flour" .
# <http://purl.org/heals/ingredient/Fahrenheit> <http://www.w3.org/2000/01/rdf-schema#label> "fahrenheit" .
# <http://purl.org/heals/ingredient/Walnut> <http://purl.org/heals/food/hasTexture> <http://purl.org/heals/ingredient/Crunchy> .
# <http://purl.org/heals/ingredient/PumpkinSeed> <http://www.w3.org/2004/02/skos/core#definition> "the edible seed of a pumpkin" .
# <http://purl.org/heals/ingredient/Minute> <http://purl.org/dc/terms/source> "Dictionary.com, \"minute.\" [Online]. Available: https://www.dictionary.com/browse/minute?s=t. [Accessed Oct. 5, 2018]" .
# <http://purl.org/heals/ingredient/Salt> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/SesameOil> <http://www.w3.org/2000/01/rdf-schema#label> "sesame oil" .
# <http://purl.org/heals/ingredient/Moist> <http://www.w3.org/2000/01/rdf-schema#label> "moist" .
# <http://purl.org/heals/ingredient/Onion> <http://purl.org/dc/terms/source> "\"Onion ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/onion. [Accessed: 26-Oct-2018]." .
# <http://purl.org/heals/ingredient/Cilantro> <http://www.w3.org/2004/02/skos/core#definition> "the strong-scented leaves of the coriander plant, used in salads or to flavor and garnish food" .
# <http://purl.org/heals/ingredient/KamutFlour> <http://purl.org/heals/food/hasGluten> "true"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/WhiteVinegar> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Water> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/LemonJuice> <http://www.w3.org/2000/01/rdf-schema#label> "lemon juice" .
# <http://purl.org/heals/ingredient/Butter> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/CornSyrup> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Potato> <http://www.w3.org/2000/01/rdf-schema#label> "potato" .
# <http://purl.org/heals/ingredient/ChuckRoast> <http://purl.org/dc/terms/source> "\"Chuck steak,\" WIKIPEDIA [Online]. Available: https://en.wikipedia.org/wiki/Chuck_steak [Accessed: 26-Oct-2018]." .
# <http://purl.org/heals/ingredient/AllPurposeFlour> <http://purl.org/heals/food/hasGlycemicIndex> "71"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/GlutenFreeFlour> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Nutty> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/BlackPepper> <http://purl.org/heals/food/hasGlycemicIndex> "5"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/CanolaOil> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/WholeGrainMustard> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Walnut> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Smoky> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a flavor" .
# <http://purl.org/heals/ingredient/Water> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Mayonnaise> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/Cornstarch> <http://purl.org/dc/terms/source> "\"Cornstarch ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/cornstarch. [Accessed: 26-Oct-2018]." .
# <http://purl.org/heals/ingredient/Cheese> <http://www.w3.org/2004/02/skos/core#definition> "the curd of milk separated from the whey and prepared in many ways as a food" .
# <http://purl.org/heals/ingredient/Salty> <http://purl.org/dc/terms/source> "\"Salty,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/salty. [Accessed: 18-Oct-2018]." .
# <http://purl.org/heals/ingredient/BalsamicVinegar> <http://www.w3.org/2000/01/rdf-schema#label> "balsamic vinegar" .
# <http://purl.org/heals/ingredient/Chicken> <http://purl.org/dc/terms/source> "\"Chicken,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/chicken. [Accessed: 13-Oct-2018]." .
# <http://purl.org/heals/ingredient/GlutenFreeFlour> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400759> .
# <http://purl.org/heals/ingredient/Bacon> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Creamy> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as a texture" .
# <http://purl.org/heals/ingredient/LemonJuice> <http://purl.org/heals/food/hasGlycemicIndex> "20"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Pecan> <http://purl.org/heals/food/hasTexture> <http://purl.org/heals/ingredient/Crunchy> .
# <http://purl.org/heals/ingredient/VegetableOil> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Lamb> <http://www.w3.org/2004/02/skos/core#definition> "the meat of sheep" .
# <http://purl.org/heals/ingredient/ChayoteSquash> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Lamb> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/Garlic> <http://www.w3.org/2004/02/skos/core#definition> "widely cultivated for its pungent compound bulbs much used in cookery" .
# <http://purl.org/heals/ingredient/Cilantro> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Parsley> <http://www.w3.org/2004/02/skos/core#scopeNote> "used as an ingredient" .
# <http://purl.org/heals/ingredient/OliveOil> <http://purl.org/dc/terms/source> "\"Olive oil,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/olive%20oil. [Accessed: 1-Nov-2018]" .
# <http://purl.org/heals/ingredient/Almond> <http://purl.org/heals/food/hasGluten> "false"^^<http://www.w3.org/2001/XMLSchema#boolean> .
# <http://purl.org/heals/ingredient/GreenOnion> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Cheese> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Coconut> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/> <http://www.w3.org/2000/01/rdf-schema#label> "What to Make Individuals" .
# <http://purl.org/heals/ingredient/BakingSoda> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Banana> <http://purl.org/heals/food/hasGlycemicIndex> "55"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/Cilantro> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/BalsamicVinegar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.obolibrary.org/obo/FOODON_03400760> .
# <http://purl.org/heals/ingredient/Bitter> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#NamedIndividual> .
# <http://purl.org/heals/ingredient/Carrot> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/Crunchy> <http://purl.org/dc/terms/source> "\"Crunchy,\" Dictionary.com. [Online]. Available: https://www.dictionary.com/browse/crunchy?s=t. [Accessed: 12-Oct-2018]." .
# <http://purl.org/heals/ingredient/Honey> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/> <http://purl.org/dc/terms/references> "https://tw.rpi.edu/web/Courses/Ontologies/2018/Project2/maintenance" .
# <http://purl.org/heals/ingredient/Chicken> <http://purl.org/heals/food/hasGlycemicIndex> "0"^^<http://www.w3.org/2001/XMLSchema#nonNegativeInteger> .
# <http://purl.org/heals/ingredient/CowMilk> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/MilkFromCow> .
# <http://purl.org/heals/ingredient/ChuckRoast> <http://www.w3.org/2004/02/skos/core#definition> "a cut of beef and is part of the sub primal cut known as the chuck" .
# <http://purl.org/heals/ingredient/Parsley> <http://purl.org/dc/terms/source> "\"Parsley ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/parsley. [Accessed: 26-Oct-2018]." .
# <http://purl.org/heals/ingredient/PumpkinSeed> <http://purl.org/dc/terms/source> "\"pumpkin seed - Dictionary Definition,\" Vocabulary.com. [Online]. Available: https://www.vocabulary.com/dictionary/pumpkin seed. [Accessed: 12-Oct-2018]." .
# <http://purl.org/heals/ingredient/Cheese> <http://www.w3.org/2000/01/rdf-schema#label> "cheese" .
# <http://purl.org/heals/ingredient/AppleCiderVinegar> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://purl.org/heals/food/Ingredient> .
# <http://purl.org/heals/ingredient/CowMilk> <http://www.w3.org/2004/02/skos/core#definition> "milk obtained from a cow" .
# <http://purl.org/heals/ingredient/Tomato> <http://www.w3.org/2004/02/skos/core#definition> "the usually large, rounded, edible, pulpy berry of an herb (genus Solanum) of the nightshade family native to South America that is typically red but may be yellow, orange, green, or purplish in color and is eaten raw or cooked as a vegetable" .
# <http://purl.org/heals/ingredient/WholeWheatFlour> <http://purl.org/heals/food/substitutesFor> <http://purl.org/heals/ingredient/AllPurposeFlour> .
# <http://purl.org/heals/ingredient/Parsley> <http://www.w3.org/2000/01/rdf-schema#label> "parsley" .

# %%
#save the graph in ttl format
def save_graph(g, file_name, f):
    file = open("./data/"+file_name+"."+f, "x")
    file.write(g.serialize(format=f))
#     print(g.serialize(format=f))
    file.close()
g = Graph()
g.parse("./data/ingredients.rdf")

# save_graph(g, "demo_save", "ttl")
# Out:
# <Graph identifier=Nb44908df607444af987552cc9bbab743 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ##  Merging graphs
#
# Merging graphs can be done via sequential parsings or by the overloaded operator +
#
# **Note:** Set-theoretic graph semantics apply
#
# The Food knowledge graph FoodKG contains a graph of statements about ingredients, as well as a graph with statements about recipes.
#
# **Exercise 3**:
#
# 1. load ./data/ingredients.rdf and ./data/ghostbusters.ttl into a single graph, either by sequential parsing or using the operator +.
#
# 2. count the number of statements in each graph, and the intersection of the two graphs.
#
# 3. check whether the combined graph is connected (using graph.connected())
#
# 4. load ./data/ingredients.rdf and ./data/recipes.rdf into a single graph, either by sequential parsing or using the operator +.
#
# 5. count the number of statements in each graph, and the intersection of the two graphs.
#
# 6. check whether the combined graph is connected (using graph.connected()). Explain the result with respect to point 3!

# %%
#look at rdflib documentation - Navigating Graphs
g = Graph()

g1 = g.parse("./data/ghostbusters.ttl")

g = Graph()

g2 = g.parse("./data/ingredients.rdf")

# print(g2.serialize(format='ttl'))

print(len(g1))

print(len(g2))

g3 = g1 + g2

print(len(g3))

print(len(g1 & g2))


g3.connected()
# Out:
# 52337
# 837
# 53174
# 0
# False

# %%
g = Graph()

g1 = g.parse("./data/recipes.rdf")

g = Graph()

g2 = g.parse("./data/ingredients.rdf")

# print(g2.serialize(format='ttl'))

print(len(g1))

print(len(g2))

g3 = g1 + g2

print(len(g3))

print(len(g1 & g2))


g1.connected()
# Out:
# 480
# 837
# 1299
# 18
# False

# %%
g = Graph()

g1 = g.parse("./data/recipes.rdf")

# g = Graph()

g2 = g.parse("./data/ingredients.rdf")

# print(g2.serialize(format='ttl'))

# print(len(g1))

# print(len(g2))

# g3 = g1 + g2

# print(len(g3))

# print(len(g1 & g2))


g2.connected()
# Out:
# False

# %% [markdown]
# ## Namespaces
#
# Remind yourself what namespaces are.
#
# In RDFLib, the namespace module defines many common namespaces such as RDF, RDFS, OWL, FOAF, SKOS, etc., but you can also easily add URIs within a different namespace:

# %%
TEACH = Namespace("http://linkedscience.org/teach/ns#")
TEACH.Teacher
# Out:
# rdflib.term.URIRef('http://linkedscience.org/teach/ns#Teacher')

# %% [markdown]
# Check out the specification to see which other terms are used within the TEACH namespace. http://linkedscience.org/teach/ns/#sec-specification.
# You can use a NamespaceManager to bind a prefix to a namespace:

# %%
g = Graph()
g.namespace_manager.bind('TEACH', URIRef('http://linkedscience.org/teach/ns#'))
TEACH.Teacher.n3(g.namespace_manager)
# Out:
# 'TEACH:Teacher'

# %%
KRW = Namespace("http://krw.vu.nl/data#")

#creating individuals within your namespace
print(KRW.Teacher)
print(KRW.Student)
# Out:
# http://krw.vu.nl/data#Teacher
# http://krw.vu.nl/data#Student

# %%
g = Graph()
g.namespace_manager.bind('KWR', URIRef('http://krw.vu.nl.data#'))

print(g.serialize(format='ttl'))

# %% [markdown]
# **Exercise 4:**
# 1. create your own namespace (can be made up)

# %% [markdown]
# ## Creating RDF triples
#
# Triples are added to the graph with the function Graph.add()
#
# The parameter is a triple given in a Python **tuple** (subject, predicate, object)
#
# Notice the namespace convenience syntax!
#
# **Exercise 5:**
#
# 1. create a new graph and add triples (~10) within your made-up namespace using Graph.add(). These triples can be about anything, for instance ingredients or recipes. Make sure they include the predicates RDF.type, RDFS.label and RDFS.subClassOf
#
# 2. open yourRDF.ttl, and write your triples out by hand in a syntax of your choice (turtle is recommended, notice the file extension!). Load the triples here with rdflib.

# %%
#create graph

g = Graph()

#example namespace

TEACH = Namespace("http://krw.vu.nl/data#")

g.namespace_manager.bind('TEACH', URIRef('http://linkedscience.org/teach/ns#'))
g.bind("teach", TEACH)
g.bind("foaf", FOAF)
TEACH.Teacher.n3(g.namespace_manager)

# Add triples using store's add method.

bob = URIRef("http://example.org/people/Bob")
name_b = Literal("Bob")
age_b = Literal(24)


linda = URIRef("http://example.org/people/Linda")  # a GUID is generated
name_l = Literal("Linda")
age_l = Literal(40)

# s_group = BNode()



KRW_course = BNode()
g.add((KRW_course, RDF.type, TEACH.Course))
g.add((KRW_course, TEACH.hasTitle, Literal("Knowledge Representation on the Web")))
g.add((KRW_course, TEACH.hasDescription, Literal("Weekly fun stuff")))

g.add((bob, RDF.type, FOAF.Person))
g.add((bob, FOAF.name, name_b))
g.add((bob, FOAF.age, age_b))
g.add((bob, FOAF.knows, linda))
g.add((linda, RDF.type, FOAF.Person))
g.add((linda, FOAF.name, name_l))
g.add((linda, FOAF.age, age_l))

g.add((linda, RDF.type, TEACH.Teacher))
g.add((bob, RDF.type, TEACH.Student))


g.add((linda, TEACH.teacherOf, KRW_course))

print(g.serialize(format='ttl'))
# Out:
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix teach: <http://krw.vu.nl/data#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://example.org/people/Bob> a teach:Student,
#         foaf:Person ;
#     foaf:age 24 ;
#     foaf:knows <http://example.org/people/Linda> ;
#     foaf:name "Bob" .
#
# <http://example.org/people/Linda> a teach:Teacher,
#         foaf:Person ;
#     teach:teacherOf [ a teach:Course ;
#             teach:hasDescription "Weekly fun stuff" ;
#             teach:hasTitle "Knowledge Representation on the Web" ] ;
#     foaf:age 40 ;
#     foaf:name "Linda" .

# %%
#save the graph to destination in ttl format - myRDF.ttl (look at RDFLib documentation - Loading and saving RDF)
# save_graph(g, "myRDF", "ttl")
g.serialize(destination="./data/myRDF.ttl")
# Out:
# <Graph identifier=Nb3e512bf4c9b46609ba4062f90de7629 (<class 'rdflib.graph.Graph'>)>

# %%
g_new = Graph()

g_new.parse("./data/myRDF.ttl")

print(g_new.serialize(format='ttl'))
#load the saved graph and print it in ttl format
# Out:
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix teach: <http://krw.vu.nl/data#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://example.org/people/Bob> a teach:Student,
#         foaf:Person ;
#     foaf:age 24 ;
#     foaf:knows <http://example.org/people/Linda> ;
#     foaf:name "Bob" .
#
# <http://example.org/people/Linda> a teach:Teacher,
#         foaf:Person ;
#     teach:teacherOf [ a teach:Course ;
#             teach:hasDescription "Weekly fun stuff" ;
#             teach:hasTitle "Knowledge Representation on the Web" ] ;
#     foaf:age 40 ;
#     foaf:name "Linda" .

# %% [markdown]
# ## Navigating graphs
#
# rdflib uses iterators to navigate Graphs. The methods for navigating subjects, predicates and objects are Graph.subjects, Graph.predicates, Graph.objects
#
# **Exercise 6:**
#
# 1. print all the triples in yourRDF.ttl
# 2. print all subjects in yourRDF.ttl
# 3. print all predicates in yourRDF.ttl
# 4. print all objects in yourRDF.ttl

# %%
g = Graph()

g.parse("./data/myRDF.ttl")


#TIP you have to loop in the graph 
for (s, p, o) in g:
    print(f'triplet: ({s}, {p}, {o})')
    
s, p, o = [[e[i] for e in g] for i in range(3)]

print(s)
print(p)
print(o)
# Out:
# triplet: (http://example.org/people/Bob, http://xmlns.com/foaf/0.1/knows, http://example.org/people/Linda)
# triplet: (n144468f03ad84f4c8015d420c50c2d1ab1, http://krw.vu.nl/data#hasDescription, Weekly fun stuff)
# triplet: (http://example.org/people/Linda, http://xmlns.com/foaf/0.1/name, Linda)
# triplet: (n144468f03ad84f4c8015d420c50c2d1ab1, http://www.w3.org/1999/02/22-rdf-syntax-ns#type, http://krw.vu.nl/data#Course)
# triplet: (http://example.org/people/Bob, http://xmlns.com/foaf/0.1/age, 24)
# triplet: (http://example.org/people/Linda, http://krw.vu.nl/data#teacherOf, n144468f03ad84f4c8015d420c50c2d1ab1)
# triplet: (http://example.org/people/Bob, http://www.w3.org/1999/02/22-rdf-syntax-ns#type, http://xmlns.com/foaf/0.1/Person)
# triplet: (http://example.org/people/Linda, http://www.w3.org/1999/02/22-rdf-syntax-ns#type, http://krw.vu.nl/data#Teacher)
# triplet: (http://example.org/people/Bob, http://www.w3.org/1999/02/22-rdf-syntax-ns#type, http://krw.vu.nl/data#Student)
# triplet: (n144468f03ad84f4c8015d420c50c2d1ab1, http://krw.vu.nl/data#hasTitle, Knowledge Representation on the Web)
# triplet: (http://example.org/people/Linda, http://www.w3.org/1999/02/22-rdf-syntax-ns#type, http://xmlns.com/foaf/0.1/Person)
# triplet: (http://example.org/people/Linda, http://xmlns.com/foaf/0.1/age, 40)
# triplet: (http://example.org/people/Bob, http://xmlns.com/foaf/0.1/name, Bob)
# [rdflib.term.URIRef('http://example.org/people/Bob'), rdflib.term.BNode('n144468f03ad84f4c8015d420c50c2d1ab1'), rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.BNode('n144468f03ad84f4c8015d420c50c2d1ab1'), rdflib.term.URIRef('http://example.org/people/Bob'), rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.URIRef('http://example.org/people/Bob'), rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.URIRef('http://example.org/people/Bob'), rdflib.term.BNode('n144468f03ad84f4c8015d420c50c2d1ab1'), rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.URIRef('http://example.org/people/Bob')]
# [rdflib.term.URIRef('http://xmlns.com/foaf/0.1/knows'), rdflib.term.URIRef('http://krw.vu.nl/data#hasDescription'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/name'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.URIRef('http://krw.vu.nl/data#teacherOf'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://krw.vu.nl/data#hasTitle'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/name')]
# [rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.Literal('Weekly fun stuff'), rdflib.term.Literal('Linda'), rdflib.term.URIRef('http://krw.vu.nl/data#Course'), rdflib.term.Literal('24', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.BNode('n144468f03ad84f4c8015d420c50c2d1ab1'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'), rdflib.term.URIRef('http://krw.vu.nl/data#Teacher'), rdflib.term.URIRef('http://krw.vu.nl/data#Student'), rdflib.term.Literal('Knowledge Representation on the Web'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'), rdflib.term.Literal('40', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')), rdflib.term.Literal('Bob')]

# %% [markdown]
# We can also filter the subjects, predicates and objects we want to retrieve, and match their values like in a database "join" operation
#
#
# **Exercise 7:**
#
# 1. print all subject types in yourRDF.ttl
# 2. print all subject labels yourRDF.ttl

# %%
g = Graph()

g.parse("./data/myRDF.ttl")

print('\nPrinting RDF types:')
for s, p, o in g.triples((None,  RDF.type, None)):
    print(o)

print('\nPrinting RDFS labels:')
for s, p, o in g.triples((None, RDFS.label, None)):
    print(o)
# Out:
# Printing RDF types:
# http://krw.vu.nl/data#Student
# http://xmlns.com/foaf/0.1/Person
# http://xmlns.com/foaf/0.1/Person
# http://krw.vu.nl/data#Teacher
# http://krw.vu.nl/data#Course
#
# Printing RDFS labels:

# %% [markdown]
# ### Basic triple matching (almost querying!)
#
# We use method Graph.triples and a Python tuple that acts as a mask for specifying our criteria
#
# **Exercise 8:**
#
# 1. check whether a triple is in your graph -> print true or false
# 2. print all triples related to a certain subject in your graph
# 3. print all triples related to a certain object in your graph

# %%
def in_graph(s, p, o):
    return s, p, o in g.triples((None, None, None))

def get_triples_per_s(s):
    return g.triples((s, None, None))

def get_triples_per_o(o):
    return g.triples((None, None, o))

for e in get_triples_per_s(URIRef("http://example.org/people/Linda")):
    print(e)
# Out:
# (rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://krw.vu.nl/data#Teacher'))
# (rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'))
# (rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.URIRef('http://krw.vu.nl/data#teacherOf'), rdflib.term.BNode('n313fa83690e5483c9455925f6e9dfc63b1'))
# (rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'), rdflib.term.Literal('40', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://example.org/people/Linda'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/name'), rdflib.term.Literal('Linda'))

# %% [markdown]
# ## Assignment part 1: your own webapplication.
#
# You are a chef in a restaurant, and you need to serve someone that is gluten intolerant.
#
# 1. load the ./data/recipes.rdf and ./data/ingredients.rdf datasets in one graph
# 2. query your graph (as we did in previous exercises) to retrieve all recipes without gluten
# 3. query your graph for all recipes that you can make for your gluten intolerant guest.
# 4. the guest asks you whether there are more options. Can you find the recipes for which an ingredient with gluten can be replaced, solely using pattern matching? (Hint: you need to write multiple of these pattern matching queries, and check the predicate __substitutesFor__)
# 5. another guest is allergic to pecan nuts, which recipes could you serve them (including those for which pecan nuts can be replaced)
#
# **Note that this is a bit tedious: later on, we will be querying more complicated patterns with SPARQL!**

# %%
g = Graph()

g.parse("./data/recipes.rdf")
g.parse("./data/ingredients.rdf")

WTM = Namespace('http://purl.org/heals/food/')
IND = Namespace('http://purl.org/heals/ingredient/')

for ns_prefix, namespace in g.namespaces():
    print(f'{ns_prefix}: {namespace}')
print(len(g))

for o in g.predicates(unique=True):
    print(o)

#     print(f'{s}, {p}, {o}')
# Out:
# owl: http://www.w3.org/2002/07/owl#
# rdf: http://www.w3.org/1999/02/22-rdf-syntax-ns#
# rdfs: http://www.w3.org/2000/01/rdf-schema#
# xsd: http://www.w3.org/2001/XMLSchema#
# xml: http://www.w3.org/XML/1998/namespace
# wtm: http://purl.org/heals/food/
# dct: http://purl.org/dc/terms/
# skos: http://www.w3.org/2004/02/skos/core#
# obo: http://purl.obolibrary.org/obo/
# prov: http://www.w3.org/ns/prov#
# ind: http://purl.org/heals/ingredient/
# sm: https://www.omg.org/techprocess/ab/SpecificationMetadata/
# 1299
# http://purl.org/dc/terms/source
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2004/02/skos/core#scopeNote
# http://www.w3.org/2000/01/rdf-schema#label
# http://purl.org/heals/food/hasIngredient
# http://purl.org/heals/food/hasCookTime
# http://purl.org/heals/food/hasGluten
# http://www.w3.org/2004/02/skos/core#definition
# http://purl.org/heals/food/isRecommendedForMeal
# http://purl.org/heals/food/hasCookingTemperature
# http://purl.org/heals/food/substitutesFor
# http://purl.org/heals/food/isRecommendedForCourse
# http://purl.org/heals/food/serves
# https://www.omg.org/techprocess/ab/SpecificationMetadata/copyright
# http://purl.org/heals/food/hasGlycemicIndex
# http://www.w3.org/ns/prov#wasDerivedFrom
# http://purl.org/heals/food/dislikes
# http://purl.org/heals/food/forbids
# http://purl.org/dc/terms/modified
# http://purl.org/heals/food/hasTexture
# http://www.w3.org/2004/02/skos/core#editorialNote
# http://purl.org/heals/food/isAllergicTo
# http://purl.org/dc/terms/contributor
# http://www.w3.org/2004/02/skos/core#altLabel
# http://purl.org/dc/terms/description
# http://purl.org/dc/terms/publisher
# http://purl.org/dc/terms/abstract
# http://www.w3.org/2002/07/owl#imports
# http://purl.org/dc/terms/references
# http://www.w3.org/2002/07/owl#priorVersion
# http://www.w3.org/2004/02/skos/core#changeNote
# http://purl.org/dc/terms/license
# http://www.w3.org/2002/07/owl#versionIRI

# %%
def check_gluten(recipe):
    for _, _, ingredient in g.triples((recipe, WTM.hasIngredient, None)):
#         print(ingredient)
        if (ingredient, WTM.hasGluten, Literal(True)) in g:
            print(f'Recipe {recipe} has gluten! Ingredient: {ingredient}')
            return True
        
glutLessRecipes = [recipe for recipe, _, _ in g.triples((None, RDF.type, WTM.Recipe)) if not check_gluten(recipe)]

for r in glutLessRecipes:
    print(f'Recipe: {r}')
    print('ingedients:')
    for _, _, ingredient in g.triples((r, WTM.hasIngredient, None)):
        print(ingredient)
    print('\n')
    check_gluten(r)
# Out:
# Recipe http://purl.org/heals/ingredient/AlmondBiscotti has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Recipe http://purl.org/heals/ingredient/BananaBread has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Recipe http://purl.org/heals/ingredient/Brownies has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Recipe http://purl.org/heals/ingredient/ChickenSalad has gluten! Ingredient: http://purl.org/heals/ingredient/Mayonnaise
# Recipe http://purl.org/heals/ingredient/GoldenKamutBread has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Recipe http://purl.org/heals/ingredient/KamutMuffin has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Recipe http://purl.org/heals/ingredient/KamutPancake has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Recipe http://purl.org/heals/ingredient/ThaiChicken has gluten! Ingredient: http://purl.org/heals/ingredient/ChickenBroth
# Recipe http://purl.org/heals/ingredient/WhiteBread has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Recipe http://purl.org/heals/ingredient/WholeGrainBananaPancake has gluten! Ingredient: http://purl.org/heals/ingredient/WholeWheatFlour
# Recipe: http://purl.org/heals/ingredient/BakedChickenTender
# ingedients:
# http://purl.org/heals/ingredient/BlackPepper
# http://purl.org/heals/ingredient/Chicken
# http://purl.org/heals/ingredient/Garlic
# http://purl.org/heals/ingredient/LemonJuice
# http://purl.org/heals/ingredient/Salt
# http://purl.org/heals/ingredient/Tarragon
# http://purl.org/heals/ingredient/WholeGrainMustard
#
#
# Recipe: http://purl.org/heals/ingredient/BananaBlueberryAlmondFlourMuffin
# ingedients:
# http://purl.org/heals/ingredient/AlmondMeal
# http://purl.org/heals/ingredient/AppleCiderVinegar
# http://purl.org/heals/ingredient/BakingSoda
# http://purl.org/heals/ingredient/Banana
# http://purl.org/heals/ingredient/Blueberry
# http://purl.org/heals/ingredient/ChickenEgg
# http://purl.org/heals/ingredient/Honey
#
#
# Recipe: http://purl.org/heals/ingredient/BeefNilaga
# ingedients:
# http://purl.org/heals/ingredient/Beef
# http://purl.org/heals/ingredient/BeefBouillon
# http://purl.org/heals/ingredient/BlackPeppercorn
# http://purl.org/heals/ingredient/Cabbage
# http://purl.org/heals/ingredient/Carrot
# http://purl.org/heals/ingredient/Celery
# http://purl.org/heals/ingredient/ChayoteSquash
# http://purl.org/heals/ingredient/Onion
# http://purl.org/heals/ingredient/Potato
# http://purl.org/heals/ingredient/Water
#
#
# Recipe: http://purl.org/heals/ingredient/BeefStew
# ingedients:
# http://purl.org/heals/ingredient/Beef
# http://purl.org/heals/ingredient/BeefBouillon
# http://purl.org/heals/ingredient/BlackPepper
# http://purl.org/heals/ingredient/Carrot
# http://purl.org/heals/ingredient/Celery
# http://purl.org/heals/ingredient/Cornstarch
# http://purl.org/heals/ingredient/Onion
# http://purl.org/heals/ingredient/Parsley
# http://purl.org/heals/ingredient/Potato
# http://purl.org/heals/ingredient/Rosemary
# http://purl.org/heals/ingredient/VegetableOil
# http://purl.org/heals/ingredient/Water
#
#
# Recipe: http://purl.org/heals/ingredient/BraisedBalsamicChicken
# ingedients:
# http://purl.org/heals/ingredient/BalsamicVinegar
# http://purl.org/heals/ingredient/Basil
# http://purl.org/heals/ingredient/Chicken
# http://purl.org/heals/ingredient/OliveOil
# http://purl.org/heals/ingredient/Onion
# http://purl.org/heals/ingredient/Oregano
# http://purl.org/heals/ingredient/Rosemary
# http://purl.org/heals/ingredient/Salt
# http://purl.org/heals/ingredient/Thyme
# http://purl.org/heals/ingredient/Tomato
#
#
# Recipe: http://purl.org/heals/ingredient/CornedBeefHash
# ingedients:
# http://purl.org/heals/ingredient/BeefBouillon
# http://purl.org/heals/ingredient/CornedBeef
# http://purl.org/heals/ingredient/Onion
# http://purl.org/heals/ingredient/Potato
#
#
# Recipe: http://purl.org/heals/ingredient/FlourlessCoconutAndAlmondCake
# ingedients:
# http://purl.org/heals/ingredient/Almond
# http://purl.org/heals/ingredient/AlmondMeal
# http://purl.org/heals/ingredient/Butter
# http://purl.org/heals/ingredient/Coconut
# http://purl.org/heals/ingredient/ChickenEgg
# http://purl.org/heals/ingredient/VanillaExtract
# http://purl.org/heals/ingredient/WhiteSugar
#
#
# Recipe: http://purl.org/heals/ingredient/GlutenFreeCoconutCake
# ingedients:
# http://purl.org/heals/ingredient/BakingPowder
# http://purl.org/heals/ingredient/BakingSoda
# http://purl.org/heals/ingredient/Coconut
# http://purl.org/heals/ingredient/CoconutMilk
# http://purl.org/heals/ingredient/ChickenEgg
# http://purl.org/heals/ingredient/GlutenFreeFlour
# http://purl.org/heals/ingredient/Salt
# http://purl.org/heals/ingredient/VanillaExtract
# http://purl.org/heals/ingredient/VegetableOil
# http://purl.org/heals/ingredient/Walnut
# http://purl.org/heals/ingredient/WhiteSugar
#
#
# Recipe: http://purl.org/heals/ingredient/GrilledChickenKabob
# ingedients:
# http://purl.org/heals/ingredient/BlackPepper
# http://purl.org/heals/ingredient/Chicken
# http://purl.org/heals/ingredient/LemonJuice
# http://purl.org/heals/ingredient/OliveOil
# http://purl.org/heals/ingredient/Rosemary
# http://purl.org/heals/ingredient/Salt
# http://purl.org/heals/ingredient/WhiteVinegar
#
#
# Recipe: http://purl.org/heals/ingredient/PotRoastWithVegetables
# ingedients:
# http://purl.org/heals/ingredient/Basil
# http://purl.org/heals/ingredient/BeefBouillon
# http://purl.org/heals/ingredient/BlackPepper
# http://purl.org/heals/ingredient/BrownSugar
# http://purl.org/heals/ingredient/Carrot
# http://purl.org/heals/ingredient/ChuckRoast
# http://purl.org/heals/ingredient/Cornstarch
# http://purl.org/heals/ingredient/Garlic
# http://purl.org/heals/ingredient/Onion
# http://purl.org/heals/ingredient/Potato
# http://purl.org/heals/ingredient/Salt
# http://purl.org/heals/ingredient/Thyme
# http://purl.org/heals/ingredient/Tomato
# http://purl.org/heals/ingredient/Water
#
#
# Recipe: http://purl.org/heals/ingredient/SaucyShepherdPie
# ingedients:
# http://purl.org/heals/ingredient/Beef
# http://purl.org/heals/ingredient/BlackPepper
# http://purl.org/heals/ingredient/Butter
# http://purl.org/heals/ingredient/Carrot
# http://purl.org/heals/ingredient/CowMilk
# http://purl.org/heals/ingredient/Onion
# http://purl.org/heals/ingredient/Potato
# http://purl.org/heals/ingredient/Salt
#
#
# Recipe: http://purl.org/heals/ingredient/SmotheredChickenBreast
# ingedients:
# http://purl.org/heals/ingredient/Bacon
# http://purl.org/heals/ingredient/BlackPepper
# http://purl.org/heals/ingredient/BrownSugar
# http://purl.org/heals/ingredient/Cheese
# http://purl.org/heals/ingredient/Chicken
# http://purl.org/heals/ingredient/Onion
# http://purl.org/heals/ingredient/Salt
# http://purl.org/heals/ingredient/VegetableOil

# %%
g2 = Graph()

g2.parse('./data/ingredients.rdf')

for r in glutLessRecipes:
    for _, _, i in g.triples((r, WTM.hasIngredient, None)):
        if ((i, None, None)) in g2:
            print(f'{i} is in the ingedients graph!')
        else: 
            print(f'{i} is NOT in the ingedients graph!')
#     print(e[0])
# Out:
# http://purl.org/heals/ingredient/BlackPepper is in the ingedients graph!
# http://purl.org/heals/ingredient/Chicken is in the ingedients graph!
# http://purl.org/heals/ingredient/Garlic is in the ingedients graph!
# http://purl.org/heals/ingredient/LemonJuice is in the ingedients graph!
# http://purl.org/heals/ingredient/Salt is in the ingedients graph!
# http://purl.org/heals/ingredient/Tarragon is in the ingedients graph!
# http://purl.org/heals/ingredient/WholeGrainMustard is in the ingedients graph!
# http://purl.org/heals/ingredient/AlmondMeal is in the ingedients graph!
# http://purl.org/heals/ingredient/AppleCiderVinegar is in the ingedients graph!
# http://purl.org/heals/ingredient/BakingSoda is in the ingedients graph!
# http://purl.org/heals/ingredient/Banana is in the ingedients graph!
# http://purl.org/heals/ingredient/Blueberry is in the ingedients graph!
# http://purl.org/heals/ingredient/ChickenEgg is in the ingedients graph!
# http://purl.org/heals/ingredient/Honey is in the ingedients graph!
# http://purl.org/heals/ingredient/Beef is in the ingedients graph!
# http://purl.org/heals/ingredient/BeefBouillon is in the ingedients graph!
# http://purl.org/heals/ingredient/BlackPeppercorn is in the ingedients graph!
# http://purl.org/heals/ingredient/Cabbage is in the ingedients graph!
# http://purl.org/heals/ingredient/Carrot is in the ingedients graph!
# http://purl.org/heals/ingredient/Celery is in the ingedients graph!
# http://purl.org/heals/ingredient/ChayoteSquash is in the ingedients graph!
# http://purl.org/heals/ingredient/Onion is in the ingedients graph!
# http://purl.org/heals/ingredient/Potato is in the ingedients graph!
# http://purl.org/heals/ingredient/Water is in the ingedients graph!
# http://purl.org/heals/ingredient/Beef is in the ingedients graph!
# http://purl.org/heals/ingredient/BeefBouillon is in the ingedients graph!
# http://purl.org/heals/ingredient/BlackPepper is in the ingedients graph!
# http://purl.org/heals/ingredient/Carrot is in the ingedients graph!
# http://purl.org/heals/ingredient/Celery is in the ingedients graph!
# http://purl.org/heals/ingredient/Cornstarch is in the ingedients graph!
# http://purl.org/heals/ingredient/Onion is in the ingedients graph!
# http://purl.org/heals/ingredient/Parsley is in the ingedients graph!
# http://purl.org/heals/ingredient/Potato is in the ingedients graph!
# http://purl.org/heals/ingredient/Rosemary is in the ingedients graph!
# http://purl.org/heals/ingredient/VegetableOil is in the ingedients graph!
# http://purl.org/heals/ingredient/Water is in the ingedients graph!
# http://purl.org/heals/ingredient/BalsamicVinegar is in the ingedients graph!
# http://purl.org/heals/ingredient/Basil is in the ingedients graph!
# http://purl.org/heals/ingredient/Chicken is in the ingedients graph!
# http://purl.org/heals/ingredient/OliveOil is in the ingedients graph!
# http://purl.org/heals/ingredient/Onion is in the ingedients graph!
# http://purl.org/heals/ingredient/Oregano is in the ingedients graph!
# http://purl.org/heals/ingredient/Rosemary is in the ingedients graph!
# http://purl.org/heals/ingredient/Salt is in the ingedients graph!
# http://purl.org/heals/ingredient/Thyme is in the ingedients graph!
# http://purl.org/heals/ingredient/Tomato is in the ingedients graph!
# http://purl.org/heals/ingredient/BeefBouillon is in the ingedients graph!
# http://purl.org/heals/ingredient/CornedBeef is in the ingedients graph!
# http://purl.org/heals/ingredient/Onion is in the ingedients graph!
# http://purl.org/heals/ingredient/Potato is in the ingedients graph!
# http://purl.org/heals/ingredient/Almond is in the ingedients graph!
# http://purl.org/heals/ingredient/AlmondMeal is in the ingedients graph!
# http://purl.org/heals/ingredient/Butter is in the ingedients graph!
# http://purl.org/heals/ingredient/Coconut is in the ingedients graph!
# http://purl.org/heals/ingredient/ChickenEgg is in the ingedients graph!
# http://purl.org/heals/ingredient/VanillaExtract is in the ingedients graph!
# http://purl.org/heals/ingredient/WhiteSugar is in the ingedients graph!
# http://purl.org/heals/ingredient/BakingPowder is in the ingedients graph!
# http://purl.org/heals/ingredient/BakingSoda is in the ingedients graph!
# http://purl.org/heals/ingredient/Coconut is in the ingedients graph!
# http://purl.org/heals/ingredient/CoconutMilk is in the ingedients graph!
# http://purl.org/heals/ingredient/ChickenEgg is in the ingedients graph!
# http://purl.org/heals/ingredient/GlutenFreeFlour is in the ingedients graph!
# http://purl.org/heals/ingredient/Salt is in the ingedients graph!
# http://purl.org/heals/ingredient/VanillaExtract is in the ingedients graph!
# http://purl.org/heals/ingredient/VegetableOil is in the ingedients graph!
# http://purl.org/heals/ingredient/Walnut is in the ingedients graph!
# http://purl.org/heals/ingredient/WhiteSugar is in the ingedients graph!
# http://purl.org/heals/ingredient/BlackPepper is in the ingedients graph!
# http://purl.org/heals/ingredient/Chicken is in the ingedients graph!
# http://purl.org/heals/ingredient/LemonJuice is in the ingedients graph!
# http://purl.org/heals/ingredient/OliveOil is in the ingedients graph!
# http://purl.org/heals/ingredient/Rosemary is in the ingedients graph!
# http://purl.org/heals/ingredient/Salt is in the ingedients graph!
# http://purl.org/heals/ingredient/WhiteVinegar is in the ingedients graph!
# http://purl.org/heals/ingredient/Basil is in the ingedients graph!
# http://purl.org/heals/ingredient/BeefBouillon is in the ingedients graph!
# http://purl.org/heals/ingredient/BlackPepper is in the ingedients graph!
# http://purl.org/heals/ingredient/BrownSugar is in the ingedients graph!
# http://purl.org/heals/ingredient/Carrot is in the ingedients graph!
# http://purl.org/heals/ingredient/ChuckRoast is in the ingedients graph!
# http://purl.org/heals/ingredient/Cornstarch is in the ingedients graph!
# http://purl.org/heals/ingredient/Garlic is in the ingedients graph!
# http://purl.org/heals/ingredient/Onion is in the ingedients graph!
# http://purl.org/heals/ingredient/Potato is in the ingedients graph!
# http://purl.org/heals/ingredient/Salt is in the ingedients graph!
# http://purl.org/heals/ingredient/Thyme is in the ingedients graph!
# http://purl.org/heals/ingredient/Tomato is in the ingedients graph!
# http://purl.org/heals/ingredient/Water is in the ingedients graph!
# http://purl.org/heals/ingredient/Beef is in the ingedients graph!
# http://purl.org/heals/ingredient/BlackPepper is in the ingedients graph!
# http://purl.org/heals/ingredient/Butter is in the ingedients graph!
# http://purl.org/heals/ingredient/Carrot is in the ingedients graph!
# http://purl.org/heals/ingredient/CowMilk is in the ingedients graph!
# http://purl.org/heals/ingredient/Onion is in the ingedients graph!
# http://purl.org/heals/ingredient/Potato is in the ingedients graph!
# http://purl.org/heals/ingredient/Salt is in the ingedients graph!
# http://purl.org/heals/ingredient/Bacon is in the ingedients graph!
# http://purl.org/heals/ingredient/BlackPepper is in the ingedients graph!
# http://purl.org/heals/ingredient/BrownSugar is in the ingedients graph!
# http://purl.org/heals/ingredient/Cheese is in the ingedients graph!
# http://purl.org/heals/ingredient/Chicken is in the ingedients graph!
# http://purl.org/heals/ingredient/Onion is in the ingedients graph!
# http://purl.org/heals/ingredient/Salt is in the ingedients graph!
# http://purl.org/heals/ingredient/VegetableOil is in the ingedients graph!

# %%
def findSubsitude(i):
    for sub, _, _ in g.triples((None, WTM.substitutesFor, i)):
        if (sub, WTM.hasGluten, Literal(False)) in g:
#             print(f'found suitable alternative for {i}: {sub}')
            return sub

def replacable_gluten(recipe):
    for _, _, ingredient in g.triples((recipe, WTM.hasIngredient, None)):
#         print(ingredient)
        if (ingredient, WTM.hasGluten, Literal(True)) in g:
            print(f'Recipe {recipe} has gluten! Ingredient: {ingredient}')
            print(f'Gluten free subsitute exists: {findSubsitude(ingredient)}')
            return True

adjustableRecipes = [s for s, _, _ in g.triples((None, RDF.type, WTM.Recipe)) if replacable_gluten(s)]
# for s, p, o in g.triples((None, RDF.type, WTM.Recipe)):
#     replacable_gluten(s)    
print(adjustableRecipes)
# Out:
# Recipe http://purl.org/heals/ingredient/AlmondBiscotti has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Gluten free subsitute exists: http://purl.org/heals/ingredient/GlutenFreeFlour
# Recipe http://purl.org/heals/ingredient/BananaBread has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Gluten free subsitute exists: http://purl.org/heals/ingredient/GlutenFreeFlour
# Recipe http://purl.org/heals/ingredient/Brownies has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Gluten free subsitute exists: http://purl.org/heals/ingredient/GlutenFreeFlour
# Recipe http://purl.org/heals/ingredient/ChickenSalad has gluten! Ingredient: http://purl.org/heals/ingredient/Mayonnaise
# Gluten free subsitute exists: None
# Recipe http://purl.org/heals/ingredient/GoldenKamutBread has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Gluten free subsitute exists: http://purl.org/heals/ingredient/GlutenFreeFlour
# Recipe http://purl.org/heals/ingredient/KamutMuffin has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Gluten free subsitute exists: http://purl.org/heals/ingredient/GlutenFreeFlour
# Recipe http://purl.org/heals/ingredient/KamutPancake has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Gluten free subsitute exists: http://purl.org/heals/ingredient/GlutenFreeFlour
# Recipe http://purl.org/heals/ingredient/ThaiChicken has gluten! Ingredient: http://purl.org/heals/ingredient/ChickenBroth
# Gluten free subsitute exists: None
# Recipe http://purl.org/heals/ingredient/WhiteBread has gluten! Ingredient: http://purl.org/heals/ingredient/AllPurposeFlour
# Gluten free subsitute exists: http://purl.org/heals/ingredient/GlutenFreeFlour
# Recipe http://purl.org/heals/ingredient/WholeGrainBananaPancake has gluten! Ingredient: http://purl.org/heals/ingredient/WholeWheatFlour
# Gluten free subsitute exists: None
# [rdflib.term.URIRef('http://purl.org/heals/ingredient/AlmondBiscotti'), rdflib.term.URIRef('http://purl.org/heals/ingredient/BananaBread'), rdflib.term.URIRef('http://purl.org/heals/ingredient/Brownies'), rdflib.term.URIRef('http://purl.org/heals/ingredient/ChickenSalad'), rdflib.term.URIRef('http://purl.org/heals/ingredient/GoldenKamutBread'), rdflib.term.URIRef('http://purl.org/heals/ingredient/KamutMuffin'), rdflib.term.URIRef('http://purl.org/heals/ingredient/KamutPancake'), rdflib.term.URIRef('http://purl.org/heals/ingredient/ThaiChicken'), rdflib.term.URIRef('http://purl.org/heals/ingredient/WhiteBread'), rdflib.term.URIRef('http://purl.org/heals/ingredient/WholeGrainBananaPancake')]

# %%
import numpy as np

def findSubstitute(i):
    substitutes = [sub for sub, _, _ in g.triples((None, WTM.substitutesFor, i)) if ((sub, WTM.hasGluten, Literal(False)) in g and (sub != IND.Pecan))]
    return substitutes

def check_gluten(recipe):
    found_glutes = False
    substitutes = {}
    for _, _, ingredient in g.triples((recipe, WTM.hasIngredient, None)):
#         print(ingredient)
        if (ingredient, WTM.hasGluten, Literal(True)) in g:
            found_glutes = True
            ing_substitudes = findSubstitute(ingredient)
            if len(ing_substitudes) == 0:
                print(f'Did not find alternative for {ingredient}')
                return found_glutes, {}
            substitutes[ingredient] = ing_substitudes
#             print(f'Recipe {recipe} has gluten! Ingredient: {ingredient}')
            print(f'Gluten free subsitute(s) for {ingredient} exist(s): {substitutes[ingredient]}')
    return found_glutes, substitutes

def check_pecan(recipe):
    if (recipe, WTM.hasIngredient, IND.Pecan) in g:
        substitutes = {}
        print(f'Recipe {recipe} has pecan!')
        substitutes = {IND.Pecan: sub for sub, _, _ in g.triples((None, WTM.substitutesFor, IND.Pecan)) if ((sub, WTM.hasGluten, Literal(False)) in g)}
        print(f'Pecan free subsitute(s) exist(s): {substitutes[IND.Pecan]}')
        return True, substitutes
    else:
        return False, {}
     
def check_recipe(recipe):
    has_gluten, gluten_subs = check_gluten(recipe)
    has_pecan, pecan_subs = check_pecan(recipe)
    
    if (has_gluten and len(gluten_subs) == 0) or (has_pecan and len(pecan_subs) == 0):
        return False, {}, {}
    else:
        return True, gluten_subs, pecan_subs


for s, _, _ in g.triples((None, RDF.type, WTM.Recipe)):
    print(f'checking recipe {s}')
    fit, glut_alt, pec_alt = check_recipe(s)
    print(f'Fits diet restrictions: {fit}')
    if fit:
        if len(glut_alt)!=0:
            print(f'Switch these ingredients: {glut_alt.items()}')
            
        if len(pec_alt)!=0:
            print(f'Switch these ingredients: {pec_alt.items()}')
    print('\n')
    
            
# #         if (sub, WTM.hasGluten, Literal(True)):
#     for _, _, ingredient in g.triples((recipe, WTM.hasIngredient, None)):
# #         print(ingredient)
#         if (ingredient, WTM.hasGluten, Literal(True)) in g:
#             print(f'Recipe {recipe} has gluten! Ingredient: {ingredient}')
#             print(f'Gluten free subsitute exists: {findSubsitute(ingredient)}')
#             return True
# Out:
# checking recipe http://purl.org/heals/ingredient/AlmondBiscotti
# Gluten free subsitute(s) for http://purl.org/heals/ingredient/AllPurposeFlour exist(s): [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')]
# Fits diet restrictions: True
# Switch these ingredients: dict_items([(rdflib.term.URIRef('http://purl.org/heals/ingredient/AllPurposeFlour'), [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')])])
#
#
# checking recipe http://purl.org/heals/ingredient/BakedChickenTender
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/BananaBlueberryAlmondFlourMuffin
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/BananaBread
# Gluten free subsitute(s) for http://purl.org/heals/ingredient/AllPurposeFlour exist(s): [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')]
# Fits diet restrictions: True
# Switch these ingredients: dict_items([(rdflib.term.URIRef('http://purl.org/heals/ingredient/AllPurposeFlour'), [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')])])
#
#
# checking recipe http://purl.org/heals/ingredient/BeefNilaga
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/BeefStew
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/BraisedBalsamicChicken
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/Brownies
# Gluten free subsitute(s) for http://purl.org/heals/ingredient/AllPurposeFlour exist(s): [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')]
# Fits diet restrictions: True
# Switch these ingredients: dict_items([(rdflib.term.URIRef('http://purl.org/heals/ingredient/AllPurposeFlour'), [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')])])
#
#
# checking recipe http://purl.org/heals/ingredient/ChickenSalad
# Did not find alternative for http://purl.org/heals/ingredient/Mayonnaise
# Recipe http://purl.org/heals/ingredient/ChickenSalad has pecan!
# Pecan free subsitute(s) exist(s): http://purl.org/heals/ingredient/Walnut
# Fits diet restrictions: False
#
#
# checking recipe http://purl.org/heals/ingredient/CornedBeefHash
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/FlourlessCoconutAndAlmondCake
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/GlutenFreeCoconutCake
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/GoldenKamutBread
# Gluten free subsitute(s) for http://purl.org/heals/ingredient/AllPurposeFlour exist(s): [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')]
# Did not find alternative for http://purl.org/heals/ingredient/KamutFlour
# Fits diet restrictions: False
#
#
# checking recipe http://purl.org/heals/ingredient/GrilledChickenKabob
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/KamutMuffin
# Gluten free subsitute(s) for http://purl.org/heals/ingredient/AllPurposeFlour exist(s): [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')]
# Did not find alternative for http://purl.org/heals/ingredient/KamutFlour
# Fits diet restrictions: False
#
#
# checking recipe http://purl.org/heals/ingredient/KamutPancake
# Gluten free subsitute(s) for http://purl.org/heals/ingredient/AllPurposeFlour exist(s): [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')]
# Did not find alternative for http://purl.org/heals/ingredient/KamutFlour
# Fits diet restrictions: False
#
#
# checking recipe http://purl.org/heals/ingredient/PotRoastWithVegetables
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/SaucyShepherdPie
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/SmotheredChickenBreast
# Fits diet restrictions: True
#
#
# checking recipe http://purl.org/heals/ingredient/ThaiChicken
# Did not find alternative for http://purl.org/heals/ingredient/ChickenBroth
# Fits diet restrictions: False
#
#
# checking recipe http://purl.org/heals/ingredient/WhiteBread
# Gluten free subsitute(s) for http://purl.org/heals/ingredient/AllPurposeFlour exist(s): [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')]
# Fits diet restrictions: True
# Switch these ingredients: dict_items([(rdflib.term.URIRef('http://purl.org/heals/ingredient/AllPurposeFlour'), [rdflib.term.URIRef('http://purl.org/heals/ingredient/GlutenFreeFlour')])])
#
#
# checking recipe http://purl.org/heals/ingredient/WholeGrainBananaPancake
# Did not find alternative for http://purl.org/heals/ingredient/WholeWheatFlour
# Fits diet restrictions: False
